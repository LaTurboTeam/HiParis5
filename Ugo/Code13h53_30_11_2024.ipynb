# %% [markdown]
# ## Tips

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# https://github.com/nikitaprasad21/ML-Cheat-Codes/blob/main/Feature-Engineering/feature_transformation_basics.ipynb

# %% [markdown]
# #### Ordre pour agir

# %% [markdown]
# 1. Gérer les outliers (supprimer ou impute ?)
# 2. Imputation
# 3. Encoder les variables
# 4. Feature Transformation
# 5. Feature scaling
# 6. Vectoriser les features

# %% [markdown]
# #### Feature Transformation

# %% [markdown]
# Transformer les données avec trop de skewness par exemple ou pas dans la bonne range... pour que leur distrib soit normale ou autre...
#
# Certains modèles tels que : Linear & Logistic Regression nécessitent d'avoir des variables qui suivent une distribution normale.
# <br>En général, les données du monde réel suivent une normale skewed

# %% [markdown]
# **Right-skewed data => Log Transformation -> normal data:**
# *   Attention données négatives
#
# **Large values in data => Reciprocal Transformation -> small data for big values:**
# *   Attention non défini en 0
#
# **Left-skewed data => Square Transformation -> normal data:**
#
# **Un peu Right-skewed data => Square Root Transformation -> normal data:**
# *   Attention données négatives
# *   Effet plus léger sur les data que Log transf.
#
# **Large values in data => Box-Cox Transformation -> small data for big values:**
# *   Attention données > 0 (non défini même en 0)
# *   Transf. paramétrique général
# *   Estimation des paramètres optimaux par max de vraisemblance en minimisant la skewness & stabilisant la variance
#
#
# **Distrib à peu près gaussienne mais bizarre => Power Transformations -> normal data:**
# *   Transf. paramétrique général
# *   Estimation des paramètres optimaux par max de vraisemblance en minimisant la skewness & stabilisant la variance
# *   Supporte Box-Cox transformée et la transformée de Yeo-Johnson

# %% [markdown]
# #### Feature scaling

# %% [markdown]
# **Normalisation (Min Max) = Scale les valeurs dans 0 et 1**
#
# **Standardisation / Z-score normalisation = centre & réduit les données**
#
# **Standardisation robuste (par rapport aux outliers)**
#
# https://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.RobustScaler.html

# %% [markdown]
# #### Feature Extraction & Selection

# %% [markdown]
# On garde un sous groupe de features qui explique la majorité de la variance pour réduire la dimension du problème.

# %% [markdown]
# [à compléter y a VIF ...]

# %% [markdown]
# ### Imbalanced data

# %% [markdown]
# imbalanced-learn :
#
# https://imbalanced-learn.org/stable/

# %% [markdown]
# https://github.com/nikitaprasad21/ML-Cheat-Codes/blob/main/Feature-Engineering/imbalanced-data.ipynb

# %% [markdown]
# ### Other

# %% [markdown]
# **Ecrire beau rapport latex**
#
# * https://github.com/JAEarly/latextable

# %% [markdown]
# **OneHotEncoder = pour données nominales sans ordre** (chat chien renard)
#
# **OrdinalEncoder = pour données nominales avec ordre** (mauvais, bon, tres bien)
#
# **LabelEncoder = pour les labels**

# %% [markdown]
# **Pour les avoir des références à des articles scientifiques**
#
# * Medium
#     * Il y a des références à la fin des articles Medium parfois, que je pourrais ajouter lors du concours
#
#
# **Penser à regarder les hypothèses des modèles de prédiction**
#
# * naïve bayes par exemple : indépendance des prédicteurs
#
#
# **Log la target variable qu'on doit prédire ?**
#
# La variable cible est la "variable dépendante".
# <br> Si on choisit la régression linéaire, une variable dépendante non normale (non gaussienne) produira
# <br> des résidus non normaux.
#
# Solution
# <br> -> Pour rendre normale notre variable (un peu skewed par exemple) : log(target) & vérifier la nouvelle distribution
#
# p. 171 livre ds

# %% [markdown]
# **Lorsqu'on onehot encode : toujours drop 1 colonne pour éviter de créer une multicolinéarité**
#
# p. 27 livre datascience

# %% [markdown]
# **Ne pas onehot encode pour n'importe quel modèle !**
#
# p.31 livre datascience

# %% [markdown]
# **Si bcp de features, remplacer LinearRegression() de scikit par SGDRegressor()**
#
# p. 49 livre ds

# %% [markdown]
# **PCA tips**
#
# p. 61 livre ds
#
# p. 76 livre ds
#
# p. 108 livre ds

# %% [markdown]
# **Quels modèles nécessitent de normaliser / scale ses données**
#
# p. 66 livre ds

# %% [markdown]
# **Faire une webapp rapidement**
#
# p. 90 livre ds

# %% [markdown]
# **Partial training sur gros datasets**
#
# p. 94 livre ds

# %% [markdown]
# **Coefficients de corrélation**
#
# p. 111 livre ds
#
# https://pmc.ncbi.nlm.nih.gov/articles/PMC6107969/
#
# paper new ksi coefficient
#
# *   relation forte entre 2 variables
# *   corrélation périodique

# %% [markdown]
# **Paramètre de régularisation - granularité**
#
# p. 133 livre ds

# %% [markdown]
# **Ne pas overfit un arbre de décision grâce au Sankey Diagram**
#
# p. 142 livre ds
#
# p. 170 livre ds

# %% [markdown]
# **Problème scatter plot : peu y avoir du clutter - fouilli**
#
# p. 146 livre ds
#
# p. 237 livre ds

# %% [markdown]
# **Shuffle les données pour créer les train/test split**

# %% [markdown]
# **Plutôt que faire des barplots pour illustrer un propos : bubble charts**
#
# p. 188 livre ds

# %% [markdown]
# **Dès qu'une hypothèse n'est pas vérifiée régression linéaire : chercher une solution**
#
# Exemple pour hétéroscédasticité avec reg. linéaire :
#
# https://statisticsbyjim.com/regression/heteroscedasticity-regression/

# %% [markdown]
# **Preuve que violinplot / (histplot+kde) >> boxplot**
#
# Ne pas utiliser boxplot !!
#
# p. 192 livre ds

# %% [markdown]
# ## Outils Data Scientist

# %% [markdown]
# **FireDucks x27 faster vs Pandas** (dispo sous linux uniquement)

# %% [markdown]
# **icecream : debug fast variables**

# %% [markdown]
# ## Motivations techniques/Bonnes pratiques

# %% [markdown]
# *   **Est ce qu'on est en supervisé ou non supervisé ?**
#     * Modèles pour le supervisé
#         * Problème de Classification
#             * Regression logistique     # régression linéaire généralisé pour la classification
#             * Arbre de décision         : utiliser dtreeviz pour générer un graphique
#             * Random Forest
#             * Naïve Bayes               # Suppose indépendance entre les prédicteurs
#             * SVM
#             * DNN
#
#         * Problème de Régression
#             * Régression linéaire
#             * Régression polynomiale
#             * ... (voir p. 82 livre datascience)
#             *
#
#
#     * Modèles pour le non supervisé
#         * Problème de groupage - clustering
#             * KMeans++ ou Breathing KMeans (meilleur algo que KMeans simple)
#             * DBSCAN    mieux que KMeans (basé sur distrib alors que KMeans fonctionne sur clusters sphériques)
#             * ... (voir p. 42 | 103 livre datascience)
#
#
#         * Problème d'association
#         * Autoencodeurs
#             * Missing Value imputation
#             * Dimensionality Reduction
#             * Feature Extraction
#
# *   **Commencer par construire un modèle linéaire**
#     * car il faut toujours essayer de voir si le modèle le plus simple fonctionne
#     * et ensuite compléxifier si besoin
#         * XGBoostRegressor
#         * K-means
#         * SVM
#         * Réseau de neurones
#
# *   **Eviter l'underfitting**
#     * Feature selection/engineering - prendre les bonnes features
#     * Si le modèle n'est pas suffisant pour décrire la complexité des données
#         -> compléxifier le modèle
#
# *   **Eviter l'overfitting**
#     * Feature selection/engineering - prendre les bonnes features
#     * ne pas overtrain le modèle
#     * Réduction de dimension/features (PCA, VIF, régularisation...)
#     * Méthode d'ensemble learning (Stacking, bagging, boosting)
#     * Vérifier les résultats obtenus pour les Cross Validation
#         * si y a 3 plis et que le modèle fait : [13%, 78%, 47%] -> il n'arrive pas à généraliser correctement
#         * si y a 3 plis et que le modèle fait : [78%, 71%, 83%] -> on prend le modèle qui a obtenu les meilleurs résultats (83% ici)
#         * En général, K=10 plis c'est bien
#
# *   **Evaluer les performances du modèle**
#     * Explained Variance Score & R2
#         * https://stats.stackexchange.com/questions/210168/what-is-the-difference-between-r2-and-variance-score-in-scikit-learn
#     * MSE
#     * Métriques propres au cas d'utilisation du modèle (si classification : AUC ROC ou AUC PR...)
#
#     * Weighted Accuracy pour de la classification : https://store.ectap.ro/articole/1421.pdf  (p. 6 en bas)

# %% [markdown]
# **Imputation des données manquantes**
#
# *   La meilleure méthode pour données MAR est sampling de posterior (d'après mon livre Theory Decision Making) :
# <br> https://scikit-learn.org/1.5/modules/impute.html (chercher sur la page : sample_posterior=True)

# %% [markdown]
# Regarder ces notebooks

# %% [markdown]
# https://www.kaggle.com/datasets/vikrishnan/boston-house-prices/code?datasetId=1815&sortBy=voteCount

# %% [markdown]
# ### Notebooks pour comprendre le feature engineering

# %% [markdown]
# https://github.com/NishadKhudabux/Boston-House-Price-Prediction/blob/main/Boston_HousePrice_Prediction_Regression.ipynb

# %% [markdown]
# https://www.kaggle.com/code/ohseokkim/linear-nonlinear-scaling

# %% [markdown]
# ## Setup

# %%
# Import libraries for data manipulation
import pandas as pd
from summarytools import dfSummary

import numpy as np

from icecream import ic
#ic(my_var) : fait un joli print direct

from ydata_profiling import ProfileReport

# import latexify

# Import libraries for data visualization
import matplotlib.pyplot as plt
from matplotlib_inline.backend_inline import set_matplotlib_formats
set_matplotlib_formats("svg")

plt.style.use('seaborn-v0_8-whitegrid')

import seaborn as sns

import copy as cp

# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer  # noqa
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer

from statsmodels.graphics.gofplots import ProbPlot

# Import libraries for building linear regression model
from statsmodels.formula.api import ols

# Import the required function
from scipy.stats import pearsonr


import statsmodels.api as sm

from sklearn.linear_model import LinearRegression

# Import library for preparing data
from sklearn.model_selection import train_test_split

# Import library for data preprocessing
from sklearn.preprocessing import MinMaxScaler

from statsmodels.stats.outliers_influence import variance_inflation_factor

from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

# Plot q-q plot of residuals
import pylab
import scipy.stats as stats

## R2
from sklearn.metrics import r2_score


from sklearn.model_selection import cross_val_score

import warnings
warnings.filterwarnings("ignore")

# %%
def corr_plot(df, upper_tri=None, threshold=None):
    
    plt.figure(figsize = (12, 8))
    cmap = sns.diverging_palette(230, 20, as_cmap = True)

    corr = df.corr()
    mask = None

    if threshold != None:
        corr = corr.mask(np.abs(corr) < threshold, np.nan)

    if upper_tri:
        mask = np.tril(np.ones_like(corr, dtype=bool)) # affichera que le triangle supérieur

    sns.heatmap(corr, mask=mask, annot = True, fmt = '.2f', cmap = cmap)
    plt.show()

    return corr



# RMSE
# @latexify.function
def rmse(predictions, targets):
    return np.sqrt(((targets - predictions) ** 2).mean())

# MAPE
# @latexify.function
def mape(predictions, targets):
    return np.mean(np.abs((targets - predictions)) / targets) * 100

# MAE
# @latexify.function
def mae(predictions, targets):
    return np.mean(np.abs((targets - predictions)))

# %% [markdown]
# ## **Régression linéaire**

# %% [markdown]
# https://github.com/NishadKhudabux/Boston-House-Price-Prediction/blob/main/Boston_HousePrice_Prediction_Regression.ipynb

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# To Do :
#
# *   **Charger le dataset et regarder quelques lignes**  <span style="color:red">Spark</span>
# *   **Rendre exploitable le dataset** :
#     - cast une colonne string en int/float ou autre type plus adapté
#     - convertir les dates string en datetime
#     - extraire les colonnes weekday, month, year de la colonne date dd-mm-yyyy (cela permettra plus tard de discerner des tendances dans la semaine/ le mois/ les années)
#     - ...
# *   **Vérifier les dtype des colonnes** (checker qu'elles ont toute le bon type)
# *   **Checker le nombre de ligne unique par feature/colonne** (permet de checker suivant le dataset si les données sont cohérentes, parfois ok si duplicata d'info, parfois c'est pas normal)
# *   **Nombre de feature catégorielle et numérique**
# *   **Regarder les statistiques basiques pour chaque feature** (vérifier que les valeurs moyennes, std max min pas incohérent)

# %% [markdown]
# **ToDo**
#
#
# [Décrire ce que chaque ligne représente].
# <br> D'où viennent les données (source, date, contexte).
#
# Attribute informations :
#
# [expliquer chaque colonne]

# %%
df = pd.read_csv("./data/X_train_Hi5.csv")
df = df.sample(n=10_000, random_state=42)
df.head()
# Out:
#          row_index piezo_station_department_code  \
# 2613083    3067028                            33
# 1268326    1334103                            49
# 234393      246594                            27
# 1670802    1756732                            44
# 2804886    3267483                            77
#
#              piezo_station_update_date  piezo_station_investigation_depth  \
# 2613083  Fri Jun 28 07:31:38 CEST 2024                              123.0
# 1268326   Fri Jan 12 10:28:05 CET 2024                               93.5
# 234393   Mon Sep 23 19:38:51 CEST 2024                               12.0
# 1670802  Fri Jun 28 07:31:38 CEST 2024                                8.0
# 2804886  Thu Sep 19 14:26:45 CEST 2024                               15.0
#
#         piezo_station_department_name piezo_station_commune_code_insee  \
# 2613083                       Gironde                            33517
# 1268326                Maine-et-Loire                            49194
# 234393                           Eure                            27391
# 1670802              Loire-Atlantique                            44025
# 2804886                Seine-et-Marne                            77341
#
#                                     piezo_station_pe_label  \
# 2613083                              LE PORT (SOUSSANS-33)
# 1268326                           FONTAINE-MILONJurassique
# 234393        PUITS DE L'ANCIENNE GARE (MARCILLY-SUR-EURE)
# 1670802                               Forage de LA RIVIERE
# 2804886  PIÉZOMÈTRE DE NOYEN-SUR-SEINE (NOYEN-SUR-SEINE...
#
#         piezo_station_bdlisa_codes  piezo_station_altitude  \
# 2613083                ['334AG04']                    3.59
# 1268326                ['139AP14']                   40.00
# 234393                 ['121AS01']                   75.00
# 1670802                ['104AB01']                    5.00
# 2804886                ['928AC01']                   57.50
#
#         piezo_station_bss_code  ... prelev_longitude_2  prelev_latitude_2  \
# 2613083       07795X0106/PZEM9  ...                NaN                NaN
# 1268326         04552X0111/PZ2  ...          -0.281423          47.471283
# 234393           01807X0051/S1  ...           1.365070          48.713810
# 1670802         04503X0068/PZ2  ...          -1.881925          47.275110
# 2804886          02606X0112/G5  ...                NaN                NaN
#
#          prelev_commune_code_insee_2 prelev_other_volume_sum insee_%_agri  \
# 2613083                          NaN                     NaN           19
# 1268326                      49194.0              18620902.0          8.8
# 234393                       28404.0              29117529.0          1.3
# 1670802                      44045.0               8572341.0            1
# 2804886                          NaN                     NaN            0
#
#         insee_pop_commune insee_med_living_level insee_%_ind insee_%_const  \
# 2613083            1692.0                  23100         6.3          18.5
# 1268326            5815.0                  23560         8.8          12.5
# 234393             1588.0                  25340        16.6          15.9
# 1670802            4005.0                  23620        18.6          19.8
# 2804886             384.0                  24270           0           8.3
#
#          piezo_groundwater_level_category
# 2613083                           Average
# 1268326                           Average
# 234393                               High
# 1670802                           Average
# 2804886                          Very Low
#
# [5 rows x 136 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 2613083 to 1625530
# Columns: 136 entries, row_index to piezo_groundwater_level_category
# dtypes: float64(90), int64(6), object(40)
# memory usage: 10.5+ MB

# %% [markdown]
# ### Data Analysis

# %% [markdown]
# #### Analyse univariée (sur chaque colonne)

# %% [markdown]
# **To Do**
#
# [Faire des observations à l'oeil nu et suppositions sur chaque colonne]
# <br> Exemple :
#
# *   quantile 75% vaut 3.6 mais le max est à 88 : il y a des outliers
# *   0.38-0.87 with a average of 0.55. Distribution looks normal.
# *   Colonne qui a 75th percentile à la valeur max : suggère qu'il y a 2 types d'habitation dans notre cas d'étude

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_288b5 thead>tr>th {
#   text-align: left;
# }
# #T_288b5_row0_col0, #T_288b5_row1_col0, #T_288b5_row2_col0, #T_288b5_row3_col0, #T_288b5_row4_col0, #T_288b5_row5_col0, #T_288b5_row6_col0, #T_288b5_row7_col0, #T_288b5_row8_col0, #T_288b5_row9_col0, #T_288b5_row10_col0, #T_288b5_row11_col0, #T_288b5_row12_col0, #T_288b5_row13_col0, #T_288b5_row14_col0, #T_288b5_row15_col0, #T_288b5_row16_col0, #T_288b5_row17_col0, #T_288b5_row18_col0, #T_288b5_row19_col0, #T_288b5_row20_col0, #T_288b5_row21_col0, #T_288b5_row22_col0, #T_288b5_row23_col0, #T_288b5_row24_col0, #T_288b5_row25_col0, #T_288b5_row26_col0, #T_288b5_row27_col0, #T_288b5_row28_col0, #T_288b5_row29_col0, #T_288b5_row30_col0, #T_288b5_row31_col0, #T_288b5_row32_col0, #T_288b5_row33_col0, #T_288b5_row34_col0, #T_288b5_row35_col0, #T_288b5_row36_col0, #T_288b5_row37_col0, #T_288b5_row38_col0, #T_288b5_row39_col0, #T_288b5_row40_col0, #T_288b5_row41_col0, #T_288b5_row42_col0, #T_288b5_row43_col0, #T_288b5_row44_col0, #T_288b5_row45_col0, #T_288b5_row46_col0, #T_288b5_row47_col0, #T_288b5_row48_col0, #T_288b5_row49_col0, #T_288b5_row50_col0, #T_288b5_row51_col0, #T_288b5_row52_col0, #T_288b5_row53_col0, #T_288b5_row54_col0, #T_288b5_row55_col0, #T_288b5_row56_col0, #T_288b5_row57_col0, #T_288b5_row58_col0, #T_288b5_row59_col0, #T_288b5_row60_col0, #T_288b5_row61_col0, #T_288b5_row62_col0, #T_288b5_row63_col0, #T_288b5_row64_col0, #T_288b5_row65_col0, #T_288b5_row66_col0, #T_288b5_row67_col0, #T_288b5_row68_col0, #T_288b5_row69_col0, #T_288b5_row70_col0, #T_288b5_row71_col0, #T_288b5_row72_col0, #T_288b5_row73_col0, #T_288b5_row74_col0, #T_288b5_row75_col0, #T_288b5_row76_col0, #T_288b5_row77_col0, #T_288b5_row78_col0, #T_288b5_row79_col0, #T_288b5_row80_col0, #T_288b5_row81_col0, #T_288b5_row82_col0, #T_288b5_row83_col0, #T_288b5_row84_col0, #T_288b5_row85_col0, #T_288b5_row86_col0, #T_288b5_row87_col0, #T_288b5_row88_col0, #T_288b5_row89_col0, #T_288b5_row90_col0, #T_288b5_row91_col0, #T_288b5_row92_col0, #T_288b5_row93_col0, #T_288b5_row94_col0, #T_288b5_row95_col0, #T_288b5_row96_col0, #T_288b5_row97_col0, #T_288b5_row98_col0, #T_288b5_row99_col0, #T_288b5_row100_col0, #T_288b5_row101_col0, #T_288b5_row102_col0, #T_288b5_row103_col0, #T_288b5_row104_col0, #T_288b5_row105_col0, #T_288b5_row106_col0, #T_288b5_row107_col0, #T_288b5_row108_col0, #T_288b5_row109_col0, #T_288b5_row110_col0, #T_288b5_row111_col0, #T_288b5_row112_col0, #T_288b5_row113_col0, #T_288b5_row114_col0, #T_288b5_row115_col0, #T_288b5_row116_col0, #T_288b5_row117_col0, #T_288b5_row118_col0, #T_288b5_row119_col0, #T_288b5_row120_col0, #T_288b5_row121_col0, #T_288b5_row122_col0, #T_288b5_row123_col0, #T_288b5_row124_col0, #T_288b5_row125_col0, #T_288b5_row126_col0, #T_288b5_row127_col0, #T_288b5_row128_col0, #T_288b5_row129_col0, #T_288b5_row130_col0, #T_288b5_row131_col0, #T_288b5_row132_col0, #T_288b5_row133_col0, #T_288b5_row134_col0, #T_288b5_row135_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_288b5_row0_col1, #T_288b5_row1_col1, #T_288b5_row2_col1, #T_288b5_row3_col1, #T_288b5_row4_col1, #T_288b5_row5_col1, #T_288b5_row6_col1, #T_288b5_row7_col1, #T_288b5_row8_col1, #T_288b5_row9_col1, #T_288b5_row10_col1, #T_288b5_row11_col1, #T_288b5_row12_col1, #T_288b5_row13_col1, #T_288b5_row14_col1, #T_288b5_row15_col1, #T_288b5_row16_col1, #T_288b5_row17_col1, #T_288b5_row18_col1, #T_288b5_row19_col1, #T_288b5_row20_col1, #T_288b5_row21_col1, #T_288b5_row22_col1, #T_288b5_row23_col1, #T_288b5_row24_col1, #T_288b5_row25_col1, #T_288b5_row26_col1, #T_288b5_row27_col1, #T_288b5_row28_col1, #T_288b5_row29_col1, #T_288b5_row30_col1, #T_288b5_row31_col1, #T_288b5_row32_col1, #T_288b5_row33_col1, #T_288b5_row34_col1, #T_288b5_row35_col1, #T_288b5_row36_col1, #T_288b5_row37_col1, #T_288b5_row38_col1, #T_288b5_row39_col1, #T_288b5_row40_col1, #T_288b5_row41_col1, #T_288b5_row42_col1, #T_288b5_row43_col1, #T_288b5_row44_col1, #T_288b5_row45_col1, #T_288b5_row46_col1, #T_288b5_row47_col1, #T_288b5_row48_col1, #T_288b5_row49_col1, #T_288b5_row50_col1, #T_288b5_row51_col1, #T_288b5_row52_col1, #T_288b5_row53_col1, #T_288b5_row54_col1, #T_288b5_row55_col1, #T_288b5_row56_col1, #T_288b5_row57_col1, #T_288b5_row58_col1, #T_288b5_row59_col1, #T_288b5_row60_col1, #T_288b5_row61_col1, #T_288b5_row62_col1, #T_288b5_row63_col1, #T_288b5_row64_col1, #T_288b5_row65_col1, #T_288b5_row66_col1, #T_288b5_row67_col1, #T_288b5_row68_col1, #T_288b5_row69_col1, #T_288b5_row70_col1, #T_288b5_row71_col1, #T_288b5_row72_col1, #T_288b5_row73_col1, #T_288b5_row74_col1, #T_288b5_row75_col1, #T_288b5_row76_col1, #T_288b5_row77_col1, #T_288b5_row78_col1, #T_288b5_row79_col1, #T_288b5_row80_col1, #T_288b5_row81_col1, #T_288b5_row82_col1, #T_288b5_row83_col1, #T_288b5_row84_col1, #T_288b5_row85_col1, #T_288b5_row86_col1, #T_288b5_row87_col1, #T_288b5_row88_col1, #T_288b5_row89_col1, #T_288b5_row90_col1, #T_288b5_row91_col1, #T_288b5_row92_col1, #T_288b5_row93_col1, #T_288b5_row94_col1, #T_288b5_row95_col1, #T_288b5_row96_col1, #T_288b5_row97_col1, #T_288b5_row98_col1, #T_288b5_row99_col1, #T_288b5_row100_col1, #T_288b5_row101_col1, #T_288b5_row102_col1, #T_288b5_row103_col1, #T_288b5_row104_col1, #T_288b5_row105_col1, #T_288b5_row106_col1, #T_288b5_row107_col1, #T_288b5_row108_col1, #T_288b5_row109_col1, #T_288b5_row110_col1, #T_288b5_row111_col1, #T_288b5_row112_col1, #T_288b5_row113_col1, #T_288b5_row114_col1, #T_288b5_row115_col1, #T_288b5_row116_col1, #T_288b5_row117_col1, #T_288b5_row118_col1, #T_288b5_row119_col1, #T_288b5_row120_col1, #T_288b5_row121_col1, #T_288b5_row122_col1, #T_288b5_row123_col1, #T_288b5_row124_col1, #T_288b5_row125_col1, #T_288b5_row126_col1, #T_288b5_row127_col1, #T_288b5_row128_col1, #T_288b5_row129_col1, #T_288b5_row130_col1, #T_288b5_row131_col1, #T_288b5_row132_col1, #T_288b5_row133_col1, #T_288b5_row134_col1, #T_288b5_row135_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_288b5_row0_col2, #T_288b5_row1_col2, #T_288b5_row2_col2, #T_288b5_row3_col2, #T_288b5_row4_col2, #T_288b5_row5_col2, #T_288b5_row6_col2, #T_288b5_row7_col2, #T_288b5_row8_col2, #T_288b5_row9_col2, #T_288b5_row10_col2, #T_288b5_row11_col2, #T_288b5_row12_col2, #T_288b5_row13_col2, #T_288b5_row14_col2, #T_288b5_row15_col2, #T_288b5_row16_col2, #T_288b5_row17_col2, #T_288b5_row18_col2, #T_288b5_row19_col2, #T_288b5_row20_col2, #T_288b5_row21_col2, #T_288b5_row22_col2, #T_288b5_row23_col2, #T_288b5_row24_col2, #T_288b5_row25_col2, #T_288b5_row26_col2, #T_288b5_row27_col2, #T_288b5_row28_col2, #T_288b5_row29_col2, #T_288b5_row30_col2, #T_288b5_row31_col2, #T_288b5_row32_col2, #T_288b5_row33_col2, #T_288b5_row34_col2, #T_288b5_row35_col2, #T_288b5_row36_col2, #T_288b5_row37_col2, #T_288b5_row38_col2, #T_288b5_row39_col2, #T_288b5_row40_col2, #T_288b5_row41_col2, #T_288b5_row42_col2, #T_288b5_row43_col2, #T_288b5_row44_col2, #T_288b5_row45_col2, #T_288b5_row46_col2, #T_288b5_row47_col2, #T_288b5_row48_col2, #T_288b5_row49_col2, #T_288b5_row50_col2, #T_288b5_row51_col2, #T_288b5_row52_col2, #T_288b5_row53_col2, #T_288b5_row54_col2, #T_288b5_row55_col2, #T_288b5_row56_col2, #T_288b5_row57_col2, #T_288b5_row58_col2, #T_288b5_row59_col2, #T_288b5_row60_col2, #T_288b5_row61_col2, #T_288b5_row62_col2, #T_288b5_row63_col2, #T_288b5_row64_col2, #T_288b5_row65_col2, #T_288b5_row66_col2, #T_288b5_row67_col2, #T_288b5_row68_col2, #T_288b5_row69_col2, #T_288b5_row70_col2, #T_288b5_row71_col2, #T_288b5_row72_col2, #T_288b5_row73_col2, #T_288b5_row74_col2, #T_288b5_row75_col2, #T_288b5_row76_col2, #T_288b5_row77_col2, #T_288b5_row78_col2, #T_288b5_row79_col2, #T_288b5_row80_col2, #T_288b5_row81_col2, #T_288b5_row82_col2, #T_288b5_row83_col2, #T_288b5_row84_col2, #T_288b5_row85_col2, #T_288b5_row86_col2, #T_288b5_row87_col2, #T_288b5_row88_col2, #T_288b5_row89_col2, #T_288b5_row90_col2,

# %%
df.describe().T
# Out:
#                                      count          mean           std  \
# row_index                          10000.0  1.565938e+06  9.606346e+05
# piezo_station_investigation_depth   9373.0  8.766313e+01  2.552244e+02
# piezo_station_altitude             10000.0  1.481116e+02  1.973564e+02
# piezo_station_longitude            10000.0  2.235367e+00  2.720876e+00
# piezo_station_latitude             10000.0  4.637224e+01  2.190560e+00
# ...                                    ...           ...           ...
# prelev_longitude_2                  7970.0  1.984042e+00  2.633540e+00
# prelev_latitude_2                   7970.0  4.648517e+01  2.112996e+00
# prelev_commune_code_insee_2         7970.0  4.554789e+04  2.464624e+04
# prelev_other_volume_sum             8647.0  1.802884e+08  1.175160e+09
# insee_pop_commune                   9895.0  6.763457e+03  3.155288e+04
#
#                                            min           25%           50%  \
# row_index                            83.000000  7.495102e+05  1.495360e+06
# piezo_station_investigation_depth     0.000000  1.700000e+01  3.900000e+01
# piezo_station_altitude             -999.000000  4.100000e+01  1.070000e+02
# piezo_station_longitude              -4.657129 -8.349284e-02  1.974980e+00
# piezo_station_latitude               41.404117  4.439463e+01  4.632403e+01
# ...                                        ...           ...           ...
# prelev_longitude_2                   -4.731051 -2.671679e-01  1.603242e+00
# prelev_latitude_2                    42.407792  4.464749e+01  4.653357e+01
# prelev_commune_code_insee_2        1027.000000  2.608400e+04  4.110400e+04
# prelev_other_volume_sum               0.000000  7.600472e+06  1.696644e+07
# insee_pop_commune                     6.000000  4.805000e+02  1.234000e+03
#
#                                             75%           max
# row_index                          2.243262e+06  3.294076e+06
# piezo_station_investigation_depth  8.000000e+01  5.233400e+03
# piezo_station_altitude             1.870000e+02  2.150000e+03
# piezo_station_longitude            4.190530e+00  9.519890e+00
# piezo_station_latitude             4.818946e+01  5.097109e+01
# ...                                         ...           ...
# prelev_longitude_2                 3.672857e+00  8.097536e+00
# prelev_latitude_2                  4.827218e+01  5.086488e+01
# prelev_commune_code_insee_2        6.748200e+04  9.405400e+04
# prelev_other_volume_sum            3.989934e+07  2.566101e+10
# insee_pop_commune                  3.773000e+03  8.730760e+05
#
# [96 rows x 8 columns]

# %% [markdown]
# **Observations :**
#
# CRIM :
# *   right skewness avec la plupart des valeurs à 0
#
# ZN :
# *   Approche distribution uniforme
#
# [Déduire des infos à propos des maisons présentes dans ce dataset]
#
# MEDV :
# *   C'est la variable target - dépendante.
# <br> On constate qu'elle n'est pas normale (un peu skewed).
#
# En la passant au log : elle devient normale

# %%
# df['MEDV_log'] = np.log(df['MEDV'])
# sns.histplot(data = df, x = 'MEDV_log', kde = True)

# %% [markdown]
# #### Analyse bivariée

# %%
# corr_matrix = corr_plot(df, upper_tri=True, threshold=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 corr_matrix = corr_plot(df, upper_tri=True, threshold=None)
#
# Cell In[4], line 6, in corr_plot(df, upper_tri, threshold)
#       3 plt.figure(figsize = (12, 8))
#       4 cmap = sns.diverging_palette(230, 20, as_cmap = True)
# ----> 6 corr = df.corr()
#       7 mask = None
#       9 if threshold != None:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '2B'

# %%
from matplotlib.patches import Circle, Rectangle
import matplotlib.colors as mcolors

# %%
corr_plot(df, upper_tri=True, threshold=0.7)
# Out:
#           CRIM   ZN     INDUS  CHAS       NOX   RM       AGE       DIS  \
# CRIM       1.0  NaN       NaN   NaN       NaN  NaN       NaN       NaN
# ZN         NaN  1.0       NaN   NaN       NaN  NaN       NaN       NaN
# INDUS      NaN  NaN  1.000000   NaN  0.763651  NaN       NaN -0.708027
# CHAS       NaN  NaN       NaN   1.0       NaN  NaN       NaN       NaN
# NOX        NaN  NaN  0.763651   NaN  1.000000  NaN  0.731470 -0.769230
# RM         NaN  NaN       NaN   NaN       NaN  1.0       NaN       NaN
# AGE        NaN  NaN       NaN   NaN  0.731470  NaN  1.000000 -0.747881
# DIS        NaN  NaN -0.708027   NaN -0.769230  NaN -0.747881  1.000000
# RAD        NaN  NaN       NaN   NaN       NaN  NaN       NaN       NaN
# TAX        NaN  NaN  0.720760   NaN       NaN  NaN       NaN       NaN
# PTRATIO    NaN  NaN       NaN   NaN       NaN  NaN       NaN       NaN
# LSTAT      NaN  NaN       NaN   NaN       NaN  NaN       NaN       NaN
# MEDV       NaN  NaN       NaN   NaN       NaN  NaN       NaN       NaN
# MEDV_log   NaN  NaN       NaN   NaN       NaN  NaN       NaN       NaN
#
#                RAD       TAX  PTRATIO     LSTAT      MEDV  MEDV_log
# CRIM           NaN       NaN      NaN       NaN       NaN       NaN
# ZN             NaN       NaN      NaN       NaN       NaN       NaN
# INDUS          NaN  0.720760      NaN       NaN       NaN       NaN
# CHAS           NaN       NaN      NaN       NaN       NaN       NaN
# NOX            NaN       NaN      NaN       NaN       NaN       NaN
# RM             NaN       NaN      NaN       NaN       NaN       NaN
# AGE            NaN       NaN      NaN       NaN       NaN       NaN
# DIS            NaN       NaN      NaN       NaN       NaN       NaN
# RAD       1.000000  0.910228      NaN       NaN       NaN       NaN
# TAX       0.910228  1.000000      NaN       NaN       NaN       NaN
# PTRATIO        NaN       NaN      1.0       NaN       NaN       NaN
# LSTAT          NaN       NaN      NaN  1.000000 -0.737663 -0.805034
# MEDV           NaN       NaN      NaN -0.737663  1.000000  0.953155
# MEDV_log       NaN       NaN      NaN -0.805034  0.953155  1.000000

# %% [markdown]
# [Observations sur correlations avec la target var]
#
# *   [var qui a la plus grosse correl positive avec target]
# *   [var qui a la plus grosse correl négative avec target]
#
# *   [noter var qui ont une correl linéaire négative avec target : features indésirables dans notre modèle linéaire]
#
# --------------------------------------------
# [Correlations FORTES |Cov(x,y)| >= 0.7 des variables indépendantes (tout sauf target)]
#
# *   [noter ces var]

# %% [markdown]
# #####
# *   [observer la relation entre ces features]

# %% [markdown]
# ######
# **(AGE,DIS)**

# %% [markdown]
# On constate :
#
# *   une décroissance linéaire avec DIS en fonction de AGE.
#
# ->RAS

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'AGE', y = 'DIS', data = df)
plt.show()

# %% [markdown]
# ######
# **(RAD,TAX)**

# %% [markdown]
# On constate :
#
# *   Très grande corrélation MAIS aucune trend visible
#
# -> Forte corrélation possiblement dû aux outliers

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'RAD', y = 'TAX', data = df)
plt.show()

# %% [markdown]
# Vérification après avoir enlevé les outliers :

# %%
# Remove the data corresponding to high tax rate
df1 = df[df['TAX'] < 600]

# Calculate the correlation
print('The correlation between TAX and RAD is', pearsonr(df1['TAX'], df1['RAD'])[0])
# Out:
# The correlation between TAX and RAD is 0.24975731331429202

# %% [markdown]
# ######
# **(INDUS,TAX)**

# %% [markdown]
# On constate :
#
# *   TAX semble croître linéairement en fonction de INDUS
#
# -> RAS mais bizarre en soi que ces 2 variables soient liées : dépendance avec une 3ème variable ?

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'INDUS', y = 'TAX', data = df)
plt.show()

# %% [markdown]
# ######
# **(RM,MEDV)**

# %% [markdown]
# On constate :
#
# *   une croissance linéaire de MEDV en fonction de RM.
# *   La valeur de MEDV semble cappée à 50
#
# ->RAS & présence d'outliers

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'RM', y = 'MEDV', data = df)
plt.show()

# %% [markdown]
# ######
# **(LSTAT,MEDV)**

# %% [markdown]
# On constate :
#
# *   une décroissance à peu près linéaire de MEDV en fonction de LSTAT.
# *   La valeur de MEDV semble cappée à 50
#
# ->RAS & présence d'outliers

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'LSTAT', y = 'MEDV', data = df)
plt.show()

# %% [markdown]
# ######
# **(INDUS,NOX)**

# %% [markdown]
# On constate :
#
# *   une croissance linéaire de NOX en fonction de INDUS.
# *   pas d'outlier évident
#
# ->RAS

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'INDUS', y = 'NOX', data = df)
plt.show()

# %% [markdown]
# ######
# **(AGE,NOX)**

# %% [markdown]
# On constate :
#
# *   une croissance linéaire de NOX en fonction de AGE.
# *   groupe de valeurs haute de NOX possiblement outliers
#
# ->RAS & outliers

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'AGE', y = 'NOX', data = df)
plt.show()

# %% [markdown]
# ######
# **(DIS,NOX)**

# %% [markdown]
# On constate :
#
# *   une décroissance linéaire forte de NOX en fonction de DIS.
#
# ->RAS

# %%
# Scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize = (6, 6))
sns.scatterplot(x = 'DIS', y = 'NOX', data = df)
plt.show()

# %% [markdown]
# #####
# *   [noter les variables indépendantes à éliminer (possiblement dans le training set ensuite PAS MAINTENANT)]
#
#     -> quand on a une variable x : Cov(x,target) forte c'est bien
#     <br> mais
#     <br> si on a 2 variables x,y != target, avec une forte dépendance Cov(x,y),
#     <br> elles n'apporteront pas plus d'explication l'une par rapport à l'autre
#     <br> sur notre variable target puisqu'elle apportent à peu près la même info.
#     <br> (donc n'en garder qu'une des deux)

# %% [markdown]
# ### Data Pre-processing

# %% [markdown]
# To Do :
# Note :
#
# <span style="color:red">Le terme "Gérer" ne veut pas toujours dire "supprimer" !!</span>
# <br>Exemple : pour les NaN et même si on veut pour les outliers, il vaut mieux faire du missing input avec une technique qui convient : posterior sampling
#
# *   **Gérer les lignes dupliquées (entièrement)**
# *   **Gérer les valeurs Null, vides**
# *   **Gérer les valeurs vides - avec espace**
# *   **Gérer les outliers**
# *   **Gérer les autres valeurs ("Infinity", +np.inf(), -np.inf(), autres...)**
# *   **SI BESOIN - Convertir les colonnes catégorielles en numérique (pas toujours nécessaire suivant le modèle)**
#     *   (one hot encoding, ...)
# *   **Comparer la taille du dataset preprocessed et brut** (pour vérifier qu'on a pas trop enlevé de données)

# %% [markdown]
# #### Virer feature nan count => alpha%

# %% [markdown]
# proportion_nan_prct à trouver graphiquement car parfois baisser le seuil de nan n'impacte pas le nb de features conservées.

# %%
arr_nb_col_remaining = []
arr_proportion_nan_prct = np.arange(100)
for proportion_nan_prct in arr_proportion_nan_prct:
    new_df = cp.deepcopy(df)
    for col in new_df.columns:
        if new_df[col].isnull().sum() * 100 / len(df) > proportion_nan_prct:
            new_df.drop(col, axis=1, inplace=True)
    
    nb_col_remaining = new_df.shape[1]
    arr_nb_col_remaining.append(nb_col_remaining)

# %%
plt.plot(arr_proportion_nan_prct, arr_nb_col_remaining)
plt.xlabel("proportion_nan_prct toléré")
plt.ylabel("Nb features qui restent")
plt.show()

# %% [markdown]
# On peut faire :
#
# *   1er temps : modèle qui a proportion_nan_prct = 19
# *   2ème temps : modèle qui a proportion_nan_prct = 58 (pour conserver plus de features et améliorer possiblement l'explication de la variance des données)

# %%
for proportion_nan_prct in [19]:
    new_df = cp.deepcopy(df)
    for col in new_df.columns:
        if new_df[col].isnull().sum() * 100 / len(df) > proportion_nan_prct:
            new_df.drop(col, axis=1, inplace=True)

new_df.head()
# Out:
#          row_index piezo_station_department_code  \
# 2613083    3067028                            33
# 1268326    1334103                            49
# 234393      246594                            27
# 1670802    1756732                            44
# 2804886    3267483                            77
#
#              piezo_station_update_date  piezo_station_investigation_depth  \
# 2613083  Fri Jun 28 07:31:38 CEST 2024                              123.0
# 1268326   Fri Jan 12 10:28:05 CET 2024                               93.5
# 234393   Mon Sep 23 19:38:51 CEST 2024                               12.0
# 1670802  Fri Jun 28 07:31:38 CEST 2024                                8.0
# 2804886  Thu Sep 19 14:26:45 CEST 2024                               15.0
#
#         piezo_station_department_name piezo_station_commune_code_insee  \
# 2613083                       Gironde                            33517
# 1268326                Maine-et-Loire                            49194
# 234393                           Eure                            27391
# 1670802              Loire-Atlantique                            44025
# 2804886                Seine-et-Marne                            77341
#
#                                     piezo_station_pe_label  \
# 2613083                              LE PORT (SOUSSANS-33)
# 1268326                           FONTAINE-MILONJurassique
# 234393        PUITS DE L'ANCIENNE GARE (MARCILLY-SUR-EURE)
# 1670802                               Forage de LA RIVIERE
# 2804886  PIÉZOMÈTRE DE NOYEN-SUR-SEINE (NOYEN-SUR-SEINE...
#
#         piezo_station_bdlisa_codes  piezo_station_altitude  \
# 2613083                ['334AG04']                    3.59
# 1268326                ['139AP14']                   40.00
# 234393                 ['121AS01']                   75.00
# 1670802                ['104AB01']                    5.00
# 2804886                ['928AC01']                   57.50
#
#         piezo_station_bss_code  ... hydro_latitude  hydro_hydro_quantity_elab  \
# 2613083       07795X0106/PZEM9  ...      44.956972                        QmJ
# 1268326         04552X0111/PZ2  ...      47.454998                        QmJ
# 234393           01807X0051/S1  ...      48.792029                        QmJ
# 1670802         04503X0068/PZ2  ...      47.580112                        QmJ
# 2804886          02606X0112/G5  ...      48.487675                        QmJ
#
#          distance_piezo_hydro prelev_other_volume_sum insee_%_agri  \
# 2613083             12.175941                     NaN           19
# 1268326              5.032770              18620902.0          8.8
# 234393               4.340942              29117529.0          1.3
# 1670802             19.471344               8572341.0            1
# 2804886              8.484495                     NaN            0
#
#         insee_pop_commune insee_med_living_level insee_%_ind insee_%_const  \
# 2613083            1692.0                  23100         6.3          18.5
# 1268326            5815.0                  23560         8.8          12.5
# 234393             1588.0                  25340        16.6          15.9
# 1670802            4005.0                  23620        18.6          19.8
# 2804886             384.0                  24270           0           8.3
#
#          piezo_groundwater_level_category
# 2613083                           Average
# 1268326                           Average
# 234393                               High
# 1670802                           Average
# 2804886                          Very Low
#
# [5 rows x 63 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 2613083 to 1625530
# Data columns (total 63 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   row_index                          10000 non-null  int64
#  1   piezo_station_department_code      10000 non-null  object
#  2   piezo_station_update_date          10000 non-null  object
#  3   piezo_station_investigation_depth  9373 non-null   float64
#  4   piezo_station_department_name      10000 non-null  object
#  5   piezo_station_commune_code_insee   10000 non-null  object
#  6   piezo_station_pe_label             9186 non-null   object
#  7   piezo_station_bdlisa_codes         9473 non-null   object
#  8   piezo_station_altitude             10000 non-null  float64
#  9   piezo_station_bss_code             10000 non-null  object
#  10  piezo_station_commune_name         10000 non-null  object
#  11  piezo_station_longitude            10000 non-null  float64
#  12  piezo_station_latitude             10000 non-null  float64
#  13  piezo_station_bss_id               10000 non-null  object
#  14  piezo_bss_code                     10000 non-null  object
#  15  piezo_measurement_date             10000 non-null  object
#  16  piezo_obtention_mode               10000 non-null  object
#  17  piezo_status                       10000 non-null  object
#  18  piezo_qualification                10000 non-null  object
#  19  piezo_continuity_code              10000 non-null  float64
#  20  piezo_continuity_name              10000 non-null  object
#  21  piezo_producer_code                9489 non-null   float64
#  22  piezo_producer_name                9489 non-null   object
#  23  piezo_measure_nature_code          9568 non-null   object
#  24  piezo_measure_nature_name          9568 non-null   object
#  25  meteo_id                           10000 non-null  int64
#  26  meteo_name                         10000 non-null  object
#  27  meteo_latitude                     10000 non-null  float64
#  28  meteo_longitude                    10000 non-null  float64
#  29  meteo_altitude                     10000 non-null  int64
#  30  meteo_date                         10000 non-null  object
#  31  meteo_rain_height                  9906 non-null   float64
#  32  meteo_temperature_min              9128 non-null   float64
#  33  meteo_time_tn                      8777 non-null   float64
#  34  meteo_temperature_max              9139 non-null   float64
#  35  meteo_time_tx                      8786 non-null   float64
#  36  meteo_temperature_avg              8810 non-null   float64
#  37  meteo_temperature_avg_threshold    9126 non-null   float64
#  38  meteo_frost_duration               8306 non-null   float64
#  39  meteo_amplitude_tn_tx              9126 non-null   float64
#  40  meteo_temperature_avg_tntm         9126 non-null   float64
#  41  meteo_evapotranspiration_grid      8845 non-null   float64
#  42  distance_piezo_meteo               10000 non-null  float64
#  43  hydro_station_code                 10000 non-null  object
#  44  hydro_observation_date_elab        10000 non-null  object
#  45  hydro_observation_result_elab      10000 non-null  float64
#  46  hydro_status_code                  10000 non-null  int64
#  47  hydro_status_label                 10000 non-null  object
#  48  hydro_method_code                  10000 non-null  int64
#  49  hydro_method_label                 10000 non-null  object
#  50  hydro_qualification_code           10000 non-null  int64
#  51  hydro_qualification_label          10000 non-null  object
#  52  hydro_longitude                    10000 non-null  float64
#  53  hydro_latitude                     10000 non-null  float64
#  54  hydro_hydro_quantity_elab          10000 non-null  object
#  55  distance_piezo_hydro               10000 non-null  float64
#  56  prelev_other_volume_sum            8647 non-null   float64
#  57  insee_%_agri                       9895 non-null   object
#  58  insee_pop_commune                  9895 non-null   float64
#  59  insee_med_living_level             9895 non-null   object
#  60  insee_%_ind                        9895 non-null   object
#  61  insee_%_const                      9895 non-null   object
#  62  piezo_groundwater_level_category   10000 non-null  object
# dtypes: float64(26), int64(6), object(31)
# memory usage: 4.9+ MB

# %% [markdown]
# #####

# %% [markdown]
# #####

# %%
dfSummary(new_df)
# Out:
# <style type="text/css">
# #T_d4636 thead>tr>th {
#   text-align: left;
# }
# #T_d4636_row0_col0, #T_d4636_row1_col0, #T_d4636_row2_col0, #T_d4636_row3_col0, #T_d4636_row4_col0, #T_d4636_row5_col0, #T_d4636_row6_col0, #T_d4636_row7_col0, #T_d4636_row8_col0, #T_d4636_row9_col0, #T_d4636_row10_col0, #T_d4636_row11_col0, #T_d4636_row12_col0, #T_d4636_row13_col0, #T_d4636_row14_col0, #T_d4636_row15_col0, #T_d4636_row16_col0, #T_d4636_row17_col0, #T_d4636_row18_col0, #T_d4636_row19_col0, #T_d4636_row20_col0, #T_d4636_row21_col0, #T_d4636_row22_col0, #T_d4636_row23_col0, #T_d4636_row24_col0, #T_d4636_row25_col0, #T_d4636_row26_col0, #T_d4636_row27_col0, #T_d4636_row28_col0, #T_d4636_row29_col0, #T_d4636_row30_col0, #T_d4636_row31_col0, #T_d4636_row32_col0, #T_d4636_row33_col0, #T_d4636_row34_col0, #T_d4636_row35_col0, #T_d4636_row36_col0, #T_d4636_row37_col0, #T_d4636_row38_col0, #T_d4636_row39_col0, #T_d4636_row40_col0, #T_d4636_row41_col0, #T_d4636_row42_col0, #T_d4636_row43_col0, #T_d4636_row44_col0, #T_d4636_row45_col0, #T_d4636_row46_col0, #T_d4636_row47_col0, #T_d4636_row48_col0, #T_d4636_row49_col0, #T_d4636_row50_col0, #T_d4636_row51_col0, #T_d4636_row52_col0, #T_d4636_row53_col0, #T_d4636_row54_col0, #T_d4636_row55_col0, #T_d4636_row56_col0, #T_d4636_row57_col0, #T_d4636_row58_col0, #T_d4636_row59_col0, #T_d4636_row60_col0, #T_d4636_row61_col0, #T_d4636_row62_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_d4636_row0_col1, #T_d4636_row1_col1, #T_d4636_row2_col1, #T_d4636_row3_col1, #T_d4636_row4_col1, #T_d4636_row5_col1, #T_d4636_row6_col1, #T_d4636_row7_col1, #T_d4636_row8_col1, #T_d4636_row9_col1, #T_d4636_row10_col1, #T_d4636_row11_col1, #T_d4636_row12_col1, #T_d4636_row13_col1, #T_d4636_row14_col1, #T_d4636_row15_col1, #T_d4636_row16_col1, #T_d4636_row17_col1, #T_d4636_row18_col1, #T_d4636_row19_col1, #T_d4636_row20_col1, #T_d4636_row21_col1, #T_d4636_row22_col1, #T_d4636_row23_col1, #T_d4636_row24_col1, #T_d4636_row25_col1, #T_d4636_row26_col1, #T_d4636_row27_col1, #T_d4636_row28_col1, #T_d4636_row29_col1, #T_d4636_row30_col1, #T_d4636_row31_col1, #T_d4636_row32_col1, #T_d4636_row33_col1, #T_d4636_row34_col1, #T_d4636_row35_col1, #T_d4636_row36_col1, #T_d4636_row37_col1, #T_d4636_row38_col1, #T_d4636_row39_col1, #T_d4636_row40_col1, #T_d4636_row41_col1, #T_d4636_row42_col1, #T_d4636_row43_col1, #T_d4636_row44_col1, #T_d4636_row45_col1, #T_d4636_row46_col1, #T_d4636_row47_col1, #T_d4636_row48_col1, #T_d4636_row49_col1, #T_d4636_row50_col1, #T_d4636_row51_col1, #T_d4636_row52_col1, #T_d4636_row53_col1, #T_d4636_row54_col1, #T_d4636_row55_col1, #T_d4636_row56_col1, #T_d4636_row57_col1, #T_d4636_row58_col1, #T_d4636_row59_col1, #T_d4636_row60_col1, #T_d4636_row61_col1, #T_d4636_row62_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_d4636_row0_col2, #T_d4636_row1_col2, #T_d4636_row2_col2, #T_d4636_row3_col2, #T_d4636_row4_col2, #T_d4636_row5_col2, #T_d4636_row6_col2, #T_d4636_row7_col2, #T_d4636_row8_col2, #T_d4636_row9_col2, #T_d4636_row10_col2, #T_d4636_row11_col2, #T_d4636_row12_col2, #T_d4636_row13_col2, #T_d4636_row14_col2, #T_d4636_row15_col2, #T_d4636_row16_col2, #T_d4636_row17_col2, #T_d4636_row18_col2, #T_d4636_row19_col2, #T_d4636_row20_col2, #T_d4636_row21_col2, #T_d4636_row22_col2, #T_d4636_row23_col2, #T_d4636_row24_col2, #T_d4636_row25_col2, #T_d4636_row26_col2, #T_d4636_row27_col2, #T_d4636_row28_col2, #T_d4636_row29_col2, #T_d4636_row30_col2, #T_d4636_row31_col2, #T_d4636_row32_col2, #T_d4636_row33_col2, #T_d4636_row34_col2, #T_d4636_row35_col2, #T_d4636_row36_col2, #T_d4636_row37_col2, #T_d4636_row38_col2, #T_d4636_row39_col2, #T_d4636_row40_col2, #T_d4636_row41_col2, #T_d4636_row42_col2, #T_d4636_row43_col2, #T_d4636_row44_col2, #T_d4636_row45_col2, #T_d4636_row46_col2, #T_d4636_row47_col2, #T_d4636_row48_col2, #T_d4636_row49_col2, #T_d4636_row50_col2, #T_d4636_row51_col2, #T_d4636_row52_col2, #T_d4636_row53_col2, #T_d4636_row54_col2, #T_d4636_row55_col2, #T_d4636_row56_col2, #T_d4636_row57_col2, #T_d4636_row58_col2, #T_d4636_row59_col2, #T_d4636_row60_col2, #T_d4636_row61_col2, #T_d4636_row62_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_d4636_row0_col3, #T_d4636_row1_col3, #T_d4636_row2_col3, #T_d4636_row3_col3, #T_d4636_row4_col3, #T_d4636_row5_col3, #T_d4636_row6_col3, #T_d4636_row7_col3, #T_d4636_row8_col3, #T_d4636_row9_col3, #T_d4636_row10_col3, #T_d4636_row11_col3, #T_d4636_row12_col3, #T_d4636_row13_col3, #T_d4636_row14_col3, #T_d4636_row15_col3, #T_d4636_row16_col3, #T_d4636_row17_col3, #T_d4636_row18_col3, #T_d4636_row19_col3, #T_d4636_row20_col3, #T_d4636_row21_col3, #T_d4636_row22_col3, #T_d4636_row23_col3, #T_d4636_row24_col3, #T_d4636_row25_col3, #T_d4636_row26_col3, #T_d4636_row27_col3, #T_d4636_row28_col3, #T_d4636_row29_col3, #T_d4636_row30_col3, #T_d4636_row31_col3, #T_d4636_row32_col3, #T_d4636_row33_col3, #T_d4636_row34_col3, #T_d4636_row35_col3, #T_d4636_row36_col3, #T_d4636_row37_col3, #T_d4636_row38_col3, #T_d4636_row39_col3, #T_d4636_row40_col3, #T_d4636_row41_col3, #T_d4636_row42_col3, #T_d4636_row43_col3, #T_d4636_row44_col3, #T_d4636_row45_col3, #T_d4636_row46_col3, #T_d4636_row47_col3, #T_d4636_row48_col3, #T_d4636_row49_col3, #T_d4636_row50_col3, #T_d4636_row51_col3, #T_d4636_row52_col3, #T_d4636_row53_col3, #T_d4636_row54_col3, #T_d4636_row55_col3, #T_d4636_row56_col3, #T_d4636_row57_col3, #T_d4636_row58_col3, #T_d4636_row59_col3, #T_d4636_row60_col3, #T_d4636_row61_col3, #T_d4636_row62_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_d4636_row0_col4, #T_d4636_row1_col4, #T_d4636_row2_col4, #T_d4636_row3_col4, #T_d4636_row4_col4, #T_d4636_row5_col4, #T_d4636_row6_col4, #T_d4636_row7_col4, #T_d4636_row8_col4, #T_d4636_row9_col4, #T_d4636_row10_col4, #T_d4636_row11_col4, #T_d4636_row12_col4, #T_d4636_row13_col4, #T_d4636_row14_col4, #T_d4636_row15_col4, #T_d4636_row16_col4, #T_d4636_row17_col4, #T_d4636_row18_col4, #T_d4636_row19_col4, #T_d4636_row20_col4, #T_d4636_row21_col4, #T_d4636_row22_col4, #T_d4636_row23_col4, #T_d4636_row24_col4, #T_d4636_row25_col4, #T_d4636_row26_col4, #T_d4636_row27_col4, #T_d4636_row28_col4, #T_d4636_row29_col4, #T_d4636_row30_col4, #T_d4636_row31_col4, #T_d4636_row32_col4, #T_d4636_row33_col4, #T_d4636_row34_col4, #T_d4636_row35_col4, #T_d4636_row36_col4, #T_d4636_row37_col4, #T_d4636_row38_col4, #T_d4636_row39_col4, #T_d4636_row40_col4, #T_d4636_row41_col4, #T_d4636_row42_col4, #T_d4636_row43_col4, #T_d4636_row44_col4, #T_d4636_row45_col4, #T_d4636_row46_col4, #T_d4636_row47_col4, #T_d4636_row48_col4, #T_d4636_row49_col4, #T_d4636_row50_col4, #T_d4636_row51_col4, #T_d4636_row52_col4, #T_d4636_row53_col4, #T_d4636_row54_col4, #T_d4636_row55_col4, #T_d4636_row56_col4, #T_d4636_row57_col4, #T_d4636_row58_col4, #T_d4636_row59_col4, #T_d4636_row60_col4, #T_d4636_row61_col4, #T_d4636_row62_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_d4636_row0_col5, #T_d4636_row1_col5, #T_d4636_row2_col5, #T_d4636_row3_col5, #T_d4636_row4_col5, #T_d4636_row5_col5, #T_d4636_row6_col5, #T_d4636_row7_col5, #T_d4636_row8_col5, #T_d4636_row9_col5, #T_d4636_row10_col5, #T_d4636_row11_col5, #T_d4636_row12_col5, #T_d4636_row13_col5, #T_d4636_row14_col5, #T_d4636_row15_col5, #T_d4636_row16_col5, #T_d4636_row17_col5, #T_d4636_row18_col5, #T_d4636_row19_col5, #T_d4636_row20_col5, #T_d4636_row21_col5, #T_d4636_row22_col5, #T_d4636_row23_col5, #T_d4636_row24_col5, #T_d4636_row25_col5, #T_d4636_row26_col5, #T_d4636_row27_col5, #T_d4636_row28_col5, #T_d4636_row29_col5, #T_d4636_row30_col5, #T_d4636_row31_col5, #T_d4636_row32_col5, #T_d4636_row33_col5, #T_d4636_row34_col5, #T_d4636_row35_col5, #T_d4636_row36_col5, #T_d4636_row37_col5, #T_d4

# %% [markdown]
# On a déduit à la main ce qu'il fallait faire sur les 63 colonnes restantes
#
# one hot encoding
# ------------------
#
# piezo_station_department_code
# piezo_station_department_name
# piezo_obtention_mode
# piezo_status
# piezo_measure_nature_code
# hydro_status_code
# hydro_status_label
# hydro_qualification_code
# hydro_hydro_quantity_elab
#
#
#
# ordinal encoding
# ------------------
# hydro_qualification_label (douteuse, non qualifiée, bonne)
#
#
#
# décomposer la feature en numérique:
# ------------------
# piezo_measurement_date (décomposé day, month, year)
# meteo_date (décomposé day, month, year)
# hydro_observation_date_elab
#
# drop feature:
# ------------------
# piezo_station_commune_code_insee
# piezo_station_pe_label
# piezo_station_bdlisa_codes
# piezo_station_bss_code
# piezo_station_commune_name
# piezo_station_bss_id
# piezo_bss_code
# piezo_station_update_date (décomposé hour, day, month)
# piezo_qualification
# piezo_continuity_code
# piezo_continuity_name
# piezo_producer_name
# piezo_measure_nature_name
# meteo_name
# hydro_station_code
# hydro_method_code
# hydro_method_label
# insee_med_living_level
#
# parse :
# ------------------
# insee_%_agri float
# insee_%_ind
# insee_%_const
#
#
# target :
# ------------------
# piezo_groundwater_level_category

# %% [markdown]
# #### Gérer les lignes dupliquées

# %%
print(new_df.shape)
new_df.drop_duplicates(inplace=True)
print(new_df.shape)
# Out:
# (10000, 63)
# (10000, 63)

# %% [markdown]
# #### Traitement de l'analyse à la main

# %% [markdown]
# On fait sur les 63 colonnes restantes tout ce qui a été analysé à la main :

# %%
target = "piezo_groundwater_level_category"

# %% [markdown]
# ##### Drop

# %% [markdown]
# drop feature:
# ------------------
# piezo_station_commune_code_insee
# piezo_station_pe_label
# piezo_station_bdlisa_codes
# piezo_station_bss_code
# piezo_station_commune_name
# piezo_station_bss_id
# piezo_bss_code
# piezo_station_update_date (décomposé hour, day, month)
# piezo_qualification
# piezo_continuity_code
# piezo_continuity_name
# piezo_producer_name
# piezo_measure_nature_name
# meteo_name
# hydro_station_code
# hydro_method_code
# hydro_method_label
# insee_med_living_level
# meteo_id
# hydro_qualification_label
# hydro_status_code

# %%
features_to_drop = ["piezo_station_commune_code_insee",
                    "piezo_station_pe_label",
                    "piezo_station_bdlisa_codes",
                    "piezo_station_bss_code",
                    "piezo_station_commune_name",
                    "piezo_station_bss_id",
                    "piezo_bss_code",
                    "piezo_station_update_date",
                    "piezo_qualification",
                    "piezo_continuity_code",
                    "piezo_continuity_name",
                    "piezo_producer_name",
                    "piezo_measure_nature_name",
                    "meteo_name",
                    "hydro_station_code",
                    "hydro_method_code",
                    "hydro_method_label",
                    "insee_med_living_level",
                    "meteo_id",
                    "hydro_qualification_label",
                    "hydro_status_code",
                    "piezo_station_department_name"]

features = new_df.drop(features_to_drop, axis=1)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 2613083 to 1625530
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   row_index                          10000 non-null  int64
#  1   piezo_station_department_code      10000 non-null  object
#  2   piezo_station_investigation_depth  9373 non-null   float64
#  3   piezo_station_altitude             10000 non-null  float64
#  4   piezo_station_longitude            10000 non-null  float64
#  5   piezo_station_latitude             10000 non-null  float64
#  6   piezo_measurement_date             10000 non-null  object
#  7   piezo_obtention_mode               10000 non-null  object
#  8   piezo_status                       10000 non-null  object
#  9   piezo_producer_code                9489 non-null   float64
#  10  piezo_measure_nature_code          9568 non-null   object
#  11  meteo_latitude                     10000 non-null  float64
#  12  meteo_longitude                    10000 non-null  float64
#  13  meteo_altitude                     10000 non-null  int64
#  14  meteo_date                         10000 non-null  object
#  15  meteo_rain_height                  9906 non-null   float64
#  16  meteo_temperature_min              9128 non-null   float64
#  17  meteo_time_tn                      8777 non-null   float64
#  18  meteo_temperature_max              9139 non-null   float64
#  19  meteo_time_tx                      8786 non-null   float64
#  20  meteo_temperature_avg              8810 non-null   float64
#  21  meteo_temperature_avg_threshold    9126 non-null   float64
#  22  meteo_frost_duration               8306 non-null   float64
#  23  meteo_amplitude_tn_tx              9126 non-null   float64
#  24  meteo_temperature_avg_tntm         9126 non-null   float64
#  25  meteo_evapotranspiration_grid      8845 non-null   float64
#  26  distance_piezo_meteo               10000 non-null  float64
#  27  hydro_observation_date_elab        10000 non-null  object
#  28  hydro_observation_result_elab      10000 non-null  float64
#  29  hydro_status_label                 10000 non-null  object
#  30  hydro_qualification_code           10000 non-null  int64
#  31  hydro_longitude                    10000 non-null  float64
#  32  hydro_latitude                     10000 non-null  float64
#  33  hydro_hydro_quantity_elab          10000 non-null  object
#  34  distance_piezo_hydro               10000 non-null  float64
#  35  prelev_other_volume_sum            8647 non-null   float64
#  36  insee_%_agri                       9895 non-null   object
#  37  insee_pop_commune                  9895 non-null   float64
#  38  insee_%_ind                        9895 non-null   object
#  39  insee_%_const                      9895 non-null   object
#  40  piezo_groundwater_level_category   10000 non-null  object
# dtypes: float64(25), int64(3), object(13)
# memory usage: 3.2+ MB

# %%
dfSummary(features)
# Out:
# <style type="text/css">
# #T_319cc thead>tr>th {
#   text-align: left;
# }
# #T_319cc_row0_col0, #T_319cc_row1_col0, #T_319cc_row2_col0, #T_319cc_row3_col0, #T_319cc_row4_col0, #T_319cc_row5_col0, #T_319cc_row6_col0, #T_319cc_row7_col0, #T_319cc_row8_col0, #T_319cc_row9_col0, #T_319cc_row10_col0, #T_319cc_row11_col0, #T_319cc_row12_col0, #T_319cc_row13_col0, #T_319cc_row14_col0, #T_319cc_row15_col0, #T_319cc_row16_col0, #T_319cc_row17_col0, #T_319cc_row18_col0, #T_319cc_row19_col0, #T_319cc_row20_col0, #T_319cc_row21_col0, #T_319cc_row22_col0, #T_319cc_row23_col0, #T_319cc_row24_col0, #T_319cc_row25_col0, #T_319cc_row26_col0, #T_319cc_row27_col0, #T_319cc_row28_col0, #T_319cc_row29_col0, #T_319cc_row30_col0, #T_319cc_row31_col0, #T_319cc_row32_col0, #T_319cc_row33_col0, #T_319cc_row34_col0, #T_319cc_row35_col0, #T_319cc_row36_col0, #T_319cc_row37_col0, #T_319cc_row38_col0, #T_319cc_row39_col0, #T_319cc_row40_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_319cc_row0_col1, #T_319cc_row1_col1, #T_319cc_row2_col1, #T_319cc_row3_col1, #T_319cc_row4_col1, #T_319cc_row5_col1, #T_319cc_row6_col1, #T_319cc_row7_col1, #T_319cc_row8_col1, #T_319cc_row9_col1, #T_319cc_row10_col1, #T_319cc_row11_col1, #T_319cc_row12_col1, #T_319cc_row13_col1, #T_319cc_row14_col1, #T_319cc_row15_col1, #T_319cc_row16_col1, #T_319cc_row17_col1, #T_319cc_row18_col1, #T_319cc_row19_col1, #T_319cc_row20_col1, #T_319cc_row21_col1, #T_319cc_row22_col1, #T_319cc_row23_col1, #T_319cc_row24_col1, #T_319cc_row25_col1, #T_319cc_row26_col1, #T_319cc_row27_col1, #T_319cc_row28_col1, #T_319cc_row29_col1, #T_319cc_row30_col1, #T_319cc_row31_col1, #T_319cc_row32_col1, #T_319cc_row33_col1, #T_319cc_row34_col1, #T_319cc_row35_col1, #T_319cc_row36_col1, #T_319cc_row37_col1, #T_319cc_row38_col1, #T_319cc_row39_col1, #T_319cc_row40_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_319cc_row0_col2, #T_319cc_row1_col2, #T_319cc_row2_col2, #T_319cc_row3_col2, #T_319cc_row4_col2, #T_319cc_row5_col2, #T_319cc_row6_col2, #T_319cc_row7_col2, #T_319cc_row8_col2, #T_319cc_row9_col2, #T_319cc_row10_col2, #T_319cc_row11_col2, #T_319cc_row12_col2, #T_319cc_row13_col2, #T_319cc_row14_col2, #T_319cc_row15_col2, #T_319cc_row16_col2, #T_319cc_row17_col2, #T_319cc_row18_col2, #T_319cc_row19_col2, #T_319cc_row20_col2, #T_319cc_row21_col2, #T_319cc_row22_col2, #T_319cc_row23_col2, #T_319cc_row24_col2, #T_319cc_row25_col2, #T_319cc_row26_col2, #T_319cc_row27_col2, #T_319cc_row28_col2, #T_319cc_row29_col2, #T_319cc_row30_col2, #T_319cc_row31_col2, #T_319cc_row32_col2, #T_319cc_row33_col2, #T_319cc_row34_col2, #T_319cc_row35_col2, #T_319cc_row36_col2, #T_319cc_row37_col2, #T_319cc_row38_col2, #T_319cc_row39_col2, #T_319cc_row40_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_319cc_row0_col3, #T_319cc_row1_col3, #T_319cc_row2_col3, #T_319cc_row3_col3, #T_319cc_row4_col3, #T_319cc_row5_col3, #T_319cc_row6_col3, #T_319cc_row7_col3, #T_319cc_row8_col3, #T_319cc_row9_col3, #T_319cc_row10_col3, #T_319cc_row11_col3, #T_319cc_row12_col3, #T_319cc_row13_col3, #T_319cc_row14_col3, #T_319cc_row15_col3, #T_319cc_row16_col3, #T_319cc_row17_col3, #T_319cc_row18_col3, #T_319cc_row19_col3, #T_319cc_row20_col3, #T_319cc_row21_col3, #T_319cc_row22_col3, #T_319cc_row23_col3, #T_319cc_row24_col3, #T_319cc_row25_col3, #T_319cc_row26_col3, #T_319cc_row27_col3, #T_319cc_row28_col3, #T_319cc_row29_col3, #T_319cc_row30_col3, #T_319cc_row31_col3, #T_319cc_row32_col3, #T_319cc_row33_col3, #T_319cc_row34_col3, #T_319cc_row35_col3, #T_319cc_row36_col3, #T_319cc_row37_col3, #T_319cc_row38_col3, #T_319cc_row39_col3, #T_319cc_row40_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_319cc_row0_col4, #T_319cc_row1_col4, #T_319cc_row2_col4, #T_319cc_row3_col4, #T_319cc_row4_col4, #T_319cc_row5_col4, #T_319cc_row6_col4, #T_319cc_row7_col4, #T_319cc_row8_col4, #T_319cc_row9_col4, #T_319cc_row10_col4, #T_319cc_row11_col4, #T_319cc_row12_col4, #T_319cc_row13_col4, #T_319cc_row14_col4, #T_319cc_row15_col4, #T_319cc_row16_col4, #T_319cc_row17_col4, #T_319cc_row18_col4, #T_319cc_row19_col4, #T_319cc_row20_col4, #T_319cc_row21_col4, #T_319cc_row22_col4, #T_319cc_row23_col4, #T_319cc_row24_col4, #T_319cc_row25_col4, #T_319cc_row26_col4, #T_319cc_row27_col4, #T_319cc_row28_col4, #T_319cc_row29_col4, #T_319cc_row30_col4, #T_319cc_row31_col4, #T_319cc_row32_col4, #T_319cc_row33_col4, #T_319cc_row34_col4, #T_319cc_row35_col4, #T_319cc_row36_col4, #T_319cc_row37_col4, #T_319cc_row38_col4, #T_319cc_row39_col4, #T_319cc_row40_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_319cc_row0_col5, #T_319cc_row1_col5, #T_319cc_row2_col5, #T_319cc_row3_col5, #T_319cc_row4_col5, #T_319cc_row5_col5, #T_319cc_row6_col5, #T_319cc_row7_col5, #T_319cc_row8_col5, #T_319cc_row9_col5, #T_319cc_row10_col5, #T_319cc_row11_col5, #T_319cc_row12_col5, #T_319cc_row13_col5, #T_319cc_row14_col5, #T_319cc_row15_col5, #T_319cc_row16_col5, #T_319cc_row17_col5, #T_319cc_row18_col5, #T_319cc_row19_col5, #T_319cc_row20_col5, #T_319cc_row21_col5, #T_319cc_row22_col5, #T_319cc_row23_col5, #T_319cc_row24_col5, #T_319cc_row25_col5, #T_319cc_row26_col5, #T_319cc_row27_col5, #T_319cc_row28_col5, #T_319cc_row29_col5, #T_319cc_row30_col5, #T_319cc_row31_col5, #T_319cc_row32_col5, #T_319cc_row33_col5, #T_319cc_row34_col5, #T_319cc_row35_col5, #T_319cc_row36_col5, #T_319cc_row37_col5, #T_319cc_row38_col5, #T_319cc_row39_col5, #T_319cc_row40_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_319cc">
#   <caption><strong>Data Frame Summary</strong><br>features<br>Dimensions: 10,000 x 41<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_319cc_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_319cc_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_319cc_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_319cc_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_319cc_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_319cc_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_319cc_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_319cc_row0_col1" class="data row0 col1" ><strong>row_index</strong><br>[int64]</td>
#       <td id="T_319cc_row0_col2" class="data row0 col2" >Mean (sd) : 1565938.2 (960634.6)<br>min < med < max:<br>83.0 < 1495360.5 < 3294076.0<br>IQR (CV) : 1493751.2 (1.6)</td>
#       <td id="T_319cc_row0_col3" class="data row0 col3" >10,000 distinct values</td>
#       <td id="T_319cc_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_319cc_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_319cc_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_319cc_row1_col1" class="data row1 col1" ><strong>piezo_station_department_code</strong><br>[object]</td>
#       <td id="T_319cc_row1_col2" class="data row1 col2" >1. 33<br>2. 17<br>3. 34<br>4. 40<br>5. 49<br>6. 24<br>7. 68<br>8. 76<br>9. 13<br>10. 80<br>11. other</td>
#       <td id="T_319cc_row1_col3" class="data row1 col3" >577 (5.8%)<br>513 (5.1%)<br>441 (4.4%)<br>393 (3.9%)<br>386 (3.9%)<br>295 (2.9%)<br>250 (2.5%)<br>221 (2.2%)<br>214 (2.1%)<br>205 (2.1%)<br>6,505 (65.0%)</td>
#       <td id="T_319cc_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_319cc_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_319cc_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_319cc_row2_col1" class="data row2

# %% [markdown]
# features numériques :
#
# piezo_station_investigation_depth, piezo_station_altitude, piezo_station_longitude, piezo_station_latitude, piezo_producer_code, meteo_latitude, meteo_longitude, meteo_altitude, meteo_rain_height, meteo_temperature_min, meteo_time_tn, meteo_temperature_max, meteo_time_tx, meteo_temperature_avg, meteo_temperature_avg_threshold, meteo_frost_duration, meteo_amplitude_tn_tx, meteo_temperature_avg_tntm, meteo_evapotranspiration_grid, distance_piezo_meteo, hydro_observation_result_elab, hydro_longitude, hydro_latitude, distance_piezo_hydro, prelev_other_volume_sum, insee_%_agri, insee_pop_commune, insee_%_ind, insee_%_const
#
#
# features categorielles :
#
# piezo_station_department_code, piezo_station_department_name, piezo_obtention_mode, piezo_status, piezo_measure_nature_code, hydro_status_label, hydro_qualification_code, hydro_hydro_quantity_elab
#
#
# features date :
#
# piezo_measurement_date, meteo_date, hydro_observation_date_elab,

# %%
num_col_features =      ["piezo_station_investigation_depth", 
                        "piezo_station_altitude", 
                        "piezo_station_longitude", 
                        "piezo_station_latitude", 
                        "piezo_producer_code", 
                        "meteo_latitude", 
                        "meteo_longitude", 
                        "meteo_altitude", 
                        "meteo_rain_height", 
                        "meteo_temperature_min", 
                        "meteo_time_tn", 
                        "meteo_temperature_max", 
                        "meteo_time_tx", 
                        "meteo_temperature_avg", 
                        "meteo_temperature_avg_threshold",
                        "meteo_frost_duration", 
                        "meteo_amplitude_tn_tx", 
                        "meteo_temperature_avg_tntm", 
                        "meteo_evapotranspiration_grid", 
                        "distance_piezo_meteo", 
                        "hydro_observation_result_elab", 
                        "hydro_longitude",
                        "hydro_latitude", 
                        "distance_piezo_hydro", 
                        "prelev_other_volume_sum", 
                        "insee_%_agri", 
                        "insee_pop_commune", 
                        "insee_%_ind", 
                        "insee_%_const"]

num_features = features[num_col_features]

dfSummary(num_features)
# Out:
# <style type="text/css">
# #T_abf7b thead>tr>th {
#   text-align: left;
# }
# #T_abf7b_row0_col0, #T_abf7b_row1_col0, #T_abf7b_row2_col0, #T_abf7b_row3_col0, #T_abf7b_row4_col0, #T_abf7b_row5_col0, #T_abf7b_row6_col0, #T_abf7b_row7_col0, #T_abf7b_row8_col0, #T_abf7b_row9_col0, #T_abf7b_row10_col0, #T_abf7b_row11_col0, #T_abf7b_row12_col0, #T_abf7b_row13_col0, #T_abf7b_row14_col0, #T_abf7b_row15_col0, #T_abf7b_row16_col0, #T_abf7b_row17_col0, #T_abf7b_row18_col0, #T_abf7b_row19_col0, #T_abf7b_row20_col0, #T_abf7b_row21_col0, #T_abf7b_row22_col0, #T_abf7b_row23_col0, #T_abf7b_row24_col0, #T_abf7b_row25_col0, #T_abf7b_row26_col0, #T_abf7b_row27_col0, #T_abf7b_row28_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_abf7b_row0_col1, #T_abf7b_row1_col1, #T_abf7b_row2_col1, #T_abf7b_row3_col1, #T_abf7b_row4_col1, #T_abf7b_row5_col1, #T_abf7b_row6_col1, #T_abf7b_row7_col1, #T_abf7b_row8_col1, #T_abf7b_row9_col1, #T_abf7b_row10_col1, #T_abf7b_row11_col1, #T_abf7b_row12_col1, #T_abf7b_row13_col1, #T_abf7b_row14_col1, #T_abf7b_row15_col1, #T_abf7b_row16_col1, #T_abf7b_row17_col1, #T_abf7b_row18_col1, #T_abf7b_row19_col1, #T_abf7b_row20_col1, #T_abf7b_row21_col1, #T_abf7b_row22_col1, #T_abf7b_row23_col1, #T_abf7b_row24_col1, #T_abf7b_row25_col1, #T_abf7b_row26_col1, #T_abf7b_row27_col1, #T_abf7b_row28_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_abf7b_row0_col2, #T_abf7b_row1_col2, #T_abf7b_row2_col2, #T_abf7b_row3_col2, #T_abf7b_row4_col2, #T_abf7b_row5_col2, #T_abf7b_row6_col2, #T_abf7b_row7_col2, #T_abf7b_row8_col2, #T_abf7b_row9_col2, #T_abf7b_row10_col2, #T_abf7b_row11_col2, #T_abf7b_row12_col2, #T_abf7b_row13_col2, #T_abf7b_row14_col2, #T_abf7b_row15_col2, #T_abf7b_row16_col2, #T_abf7b_row17_col2, #T_abf7b_row18_col2, #T_abf7b_row19_col2, #T_abf7b_row20_col2, #T_abf7b_row21_col2, #T_abf7b_row22_col2, #T_abf7b_row23_col2, #T_abf7b_row24_col2, #T_abf7b_row25_col2, #T_abf7b_row26_col2, #T_abf7b_row27_col2, #T_abf7b_row28_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_abf7b_row0_col3, #T_abf7b_row1_col3, #T_abf7b_row2_col3, #T_abf7b_row3_col3, #T_abf7b_row4_col3, #T_abf7b_row5_col3, #T_abf7b_row6_col3, #T_abf7b_row7_col3, #T_abf7b_row8_col3, #T_abf7b_row9_col3, #T_abf7b_row10_col3, #T_abf7b_row11_col3, #T_abf7b_row12_col3, #T_abf7b_row13_col3, #T_abf7b_row14_col3, #T_abf7b_row15_col3, #T_abf7b_row16_col3, #T_abf7b_row17_col3, #T_abf7b_row18_col3, #T_abf7b_row19_col3, #T_abf7b_row20_col3, #T_abf7b_row21_col3, #T_abf7b_row22_col3, #T_abf7b_row23_col3, #T_abf7b_row24_col3, #T_abf7b_row25_col3, #T_abf7b_row26_col3, #T_abf7b_row27_col3, #T_abf7b_row28_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_abf7b_row0_col4, #T_abf7b_row1_col4, #T_abf7b_row2_col4, #T_abf7b_row3_col4, #T_abf7b_row4_col4, #T_abf7b_row5_col4, #T_abf7b_row6_col4, #T_abf7b_row7_col4, #T_abf7b_row8_col4, #T_abf7b_row9_col4, #T_abf7b_row10_col4, #T_abf7b_row11_col4, #T_abf7b_row12_col4, #T_abf7b_row13_col4, #T_abf7b_row14_col4, #T_abf7b_row15_col4, #T_abf7b_row16_col4, #T_abf7b_row17_col4, #T_abf7b_row18_col4, #T_abf7b_row19_col4, #T_abf7b_row20_col4, #T_abf7b_row21_col4, #T_abf7b_row22_col4, #T_abf7b_row23_col4, #T_abf7b_row24_col4, #T_abf7b_row25_col4, #T_abf7b_row26_col4, #T_abf7b_row27_col4, #T_abf7b_row28_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_abf7b_row0_col5, #T_abf7b_row1_col5, #T_abf7b_row2_col5, #T_abf7b_row3_col5, #T_abf7b_row4_col5, #T_abf7b_row5_col5, #T_abf7b_row6_col5, #T_abf7b_row7_col5, #T_abf7b_row8_col5, #T_abf7b_row9_col5, #T_abf7b_row10_col5, #T_abf7b_row11_col5, #T_abf7b_row12_col5, #T_abf7b_row13_col5, #T_abf7b_row14_col5, #T_abf7b_row15_col5, #T_abf7b_row16_col5, #T_abf7b_row17_col5, #T_abf7b_row18_col5, #T_abf7b_row19_col5, #T_abf7b_row20_col5, #T_abf7b_row21_col5, #T_abf7b_row22_col5, #T_abf7b_row23_col5, #T_abf7b_row24_col5, #T_abf7b_row25_col5, #T_abf7b_row26_col5, #T_abf7b_row27_col5, #T_abf7b_row28_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_abf7b">
#   <caption><strong>Data Frame Summary</strong><br>num_features<br>Dimensions: 10,000 x 29<br>Duplicates: 1</caption>
#   <thead>
#     <tr>
#       <th id="T_abf7b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_abf7b_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_abf7b_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_abf7b_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_abf7b_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_abf7b_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_abf7b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_abf7b_row0_col1" class="data row0 col1" ><strong>piezo_station_investigation_depth</strong><br>[float64]</td>
#       <td id="T_abf7b_row0_col2" class="data row0 col2" >Mean (sd) : 87.7 (255.2)<br>min < med < max:<br>0.0 < 39.0 < 5233.4<br>IQR (CV) : 63.0 (0.3)</td>
#       <td id="T_abf7b_row0_col3" class="data row0 col3" >967 distinct values</td>
#       <td id="T_abf7b_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_abf7b_row0_col5" class="data row0 col5" >627<br>(6.3%)</td>
#     </tr>
#     <tr>
#       <td id="T_abf7b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_abf7b_row1_col1" class="data row1 col1" ><strong>piezo_station_altitude</strong><br>[float64]</td>
#       <td id="T_abf7b_row1_col2" class="data row1 col2" >Mean (sd) : 148.1 (197.4)<br>min < med < max:<br>-999.0 < 107.0 < 2150.0<br>IQR (CV) : 146.0 (0.8)</td>
#       <td id="T_abf7b_row1_col3" class="data row1 col3" >1,480 distinct values</td>
#       <td id="T_abf7b_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_abf7b_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abf7b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_abf7b_row2_col1" class="data row2 col1" ><strong>piezo_station_longitude</strong><br>[float64]</td>
#       <td id="T_abf7b_row2_col2" class="data row2 col2" >Mean (sd) : 2.2 (2.7)<br>min < med < max:<br>-4.7 < 2.0 < 9.5<br>IQR (CV) : 4.3 (0.8)</td>
#       <td id="T_abf7b_row2_col3" class="data row2 col3" >2,493 distinct values</td>
#       <td id="T_abf7b_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_abf7b_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abf7b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_abf7b_row3_col1" class="data row3 col1" ><strong>piezo_station_latitude</strong><br>[float64]</td>
#       <td id="T_abf7b_row3_col2" class="data row3 col2" >Mean (sd) : 46.4 (2.2)<br>min < med < max:<br>41.4 < 46.3 < 51.0<br>IQR (CV) : 3.8 (21.2)</td>
#       <td id="T_abf7b_row3_col3" class="data row3 col3" >2,493 distinct values</td>
#       <td id="T_abf7b_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_abf7b_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_abf7b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_abf7b_row4_col1" class="data row4 col1" ><strong>piezo_producer_code</strong><br>[float64]</td>
#       <td id="T_abf7b_row4_col2" class="data row4 col2" >Mean (sd) : 5709895329113.7 (11335516318463.2)<br>min < med < max:<br>53.0 < 300.0 < 40494388800036.0<br>IQR (CV) : 928.0 (0.5)</td>
#       <td id="T_abf7b_row4_col3" class="data row4 col3" >51 distinct values</td>
#       <td id="T_abf7b_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_abf7b_row4_col5"

# %% [markdown]
# ##### Traitement des features numériques problématiques

# %% [markdown]
# dans les var insee, y a des nan bizarre en string alors que je veux traiter comme numérique

# %%
features["insee_%_const"].unique()
# Out:
# array(['18.5', '12.5', '15.9', '19.8', '8.3', '16.8', '14.3', '21.4',
#        '5.7', '52.2', '14.7', '5.9', '6', '5.2', '18', '7.4', '4.5',
#        '6.1', '6.2', '0', '75', '13.6', '34.8', '7.3', '33.7', '30.8',
#        '2.1', '41.6', '20.8', '20.7', '10.5', '12.9', '3.1', '18.1',
#        '1.3', '2.8', '7.1', '5.5', '3.4', '52.1', '18.8', '12.6', '14.6',
#        '21.1', '7.2', '4.6', '11.9', '1.5', '9', '15.2', '4.7', '2.3',
#        '36.3', '4.9', '14.4', '16.7', '8.7', '61.5', '7.6', '5.4', '8.5',
#        '26', '2.7', '4.1', '19.2', '37', '6.3', '1.2', '2.6', '0.2',
#        '8.9', '4.8', '5.8', '8.1', '3.5', '6.5', '12', '10.3', '11.1',
#        '20.6', '5.1', '8.8', '6.7', '7.8', '1', '46.6', '37.5', '5.6',
#        '12.3', '3', '17.6', '10.1', '30', '12.7', '16.4', '12.2', '9.2',
#        '7.5', '3.8', '9.4', '4', '28.1', '2', '18.2', '9.7', '31.1',
#        '10.2', '1.8', '28.6', '20', '0.4', '11.6', '5', '50', '7.7',
#        '3.6', '11', '4.3', '0.9', '19', '1.9', '11.2', '17.9', '1.6',
#        '17.7', '11.5', '23.2', '15.5', '27.3', '10.9', '0.1', '30.4',
#        '13.2', '9.6', '2.4', '23.1', '41.2', '20.9', nan, '47.8', '4.4',
#        '17.2', '8.2', '14.8', '53.8', '23.7', '6.8', '25', '5.3', '12.4',
#        '49.3', '3.3', '34.5', '7', '10.7', '31.2', '25.8', '33.3', '30.9',
#        '10.8', '24.5', '32', '16.3', '3.2', '4.2', '30.6', '40.3', '13.8',
#        '22.2', '2.9', '10', '35.1', '19.4', '25.6', '23.8', '16.2', '9.5',
#        '21.2', '8', '44.4', '18.7', '1.7', '22.6', '52.9', '31.7', '8.6',
#        '0.7', '53.1', '45.9', '10.6', '25.2', '67.1', '39.1', '20.2',
#        '78.2', '15.4', '6.6', '16.1', '11.8', '53.4', '7.9', '9.8',
#        '73.4', '13.1', '32.2', '40.7', '22.1', '32.8', '13.5', '9.9',
#        '0.3', '6.4', '23', '2.2', '14.5', '9.1', '25.7', '21', '15.3',
#        '14.9', '17.5', '24.3', '21.6', '23.9', '17', '1.1', '3.7', '13.7',
#        '6.9', '11.3', '0.8', '29.7', '41.1', '21.8', '70', '3.9', '2.5',
#        '16', '15.6', '39', '10.4', '18.3', '39.3', '27', '14', '42.9',
#        '45.8', '21.7', '17.1', '15.8', '12.8', '17.3', '38.9', '31.6',
#        '25.4', '17.8', '14.2', '36.2', '18.6', '51.4', '39.7', '31.9',
#        '13.3', '41.7', '43.6', '32.5', '28.9', '0.6', '15', '36.4',
#        '27.9', '19.6', '32.3', '8.4', '29.4', '47.7', '32.1', '22.7',
#        '26.1', '55.9', '32.4', '29.5', '44.3', '0.5', '40', '23.4',
#        '26.3', '16.9', '62.7', '24.8', '23.5', '51', '33', '35.4', '24.6',
#        '17.4', '11.4', '32.6', '34.6', '35', '13.4', '18.9', '21.5',
#        '81.2', '9.3', '33.8', '55.8', '26.7', '20.4', '13', '23.3',
#        '35.3', '16.6', '63', '37.3', '54.9', '36.5', '19.9', '26.4',
#        '19.3', '47.5', '15.7', '60.9', '15.1', '27.7', '90', '19.7',
#        '37.9', '73.3', '41.4', '22.4', '26.6', '21.3', '62.1', '14.1',
#        '35.8', '35.2', '24.4', '34.4', '26.2', '44.8', '57.9', '20.5',
#        '13.9', '43.9', '61', '57.1', '22.9', '29', '27.2', '18.4', '38.5',
#        '43.5', '69.2', '63.1', '42.6', '71.4', '34.2', '28.2', '63.6',
#        '30.7', '21.9', '48.5', 'N/A - division par 0', '45.1', '45.5',
#        '27.1', '25.9', '58.8', '1.4', '51.9', '27.8', '27.6', '60', '24',
#        '51.3', '26.8', '20.1', '47.3', '23.6', '44.1', '47.6', '41',
#        '25.5', '46.2', '62.3', '56.5', '16.5', '24.1', '66.7', '40.5',
#        '75.9', '12.1', '38.7', '39.5', '43.3', '33.6', '47.1'],
#       dtype=object)

# %%
num_features = num_features.replace('N/A - division par 0', np.nan)
num_features = num_features.replace('nan', np.nan)

# %%
for col in num_features.columns:
    num_features[col].astype("float")

# %% [markdown]
# ##### Traitement des nan dans les variables catégorielles

# %% [markdown]
# J'ai rien fait car je considère que si on a un nan, c'est une catégorie en soi.

# %% [markdown]
# ##### Imputation var. numériques par mean de la posterior

# %% [markdown]
# features numériques :
#
# piezo_station_investigation_depth, piezo_station_altitude, piezo_station_longitude, piezo_station_latitude, piezo_producer_code, meteo_latitude, meteo_longitude, meteo_altitude, meteo_rain_height, meteo_temperature_min, meteo_time_tn, meteo_temperature_max, meteo_time_tx, meteo_temperature_avg, meteo_temperature_avg_threshold, meteo_frost_duration, meteo_amplitude_tn_tx, meteo_temperature_avg_tntm, meteo_evapotranspiration_grid, distance_piezo_meteo, hydro_observation_result_elab, hydro_longitude, hydro_latitude, distance_piezo_hydro, prelev_other_volume_sum, insee_%_agri, insee_pop_commune, insee_%_ind, insee_%_const
#
#
# features categorielles :
#
# piezo_station_department_code, piezo_station_department_name, piezo_obtention_mode, piezo_status, piezo_measure_nature_code, hydro_status_code, hydro_status_label, hydro_qualification_label, hydro_hydro_quantity_elab
#
#
# features date :
#
# piezo_measurement_date, meteo_date, hydro_observation_date_elab,

# %%
imputer_mean_posterior = IterativeImputer(random_state=42, sample_posterior=True)
imputer_mean_posterior.fit(num_features)
# Out:
# IterativeImputer(random_state=42, sample_posterior=True)

# %%
values_imputed = imputer_mean_posterior.transform(num_features)

# %%
num_features = pd.DataFrame(values_imputed)
num_features.columns = num_col_features
num_features
# Out:
#       piezo_station_investigation_depth  piezo_station_altitude  \
# 0                                123.00                    3.59
# 1                                 93.50                   40.00
# 2                                 12.00                   75.00
# 3                                  8.00                    5.00
# 4                                 15.00                   57.50
# ...                                 ...                     ...
# 9995                             138.86                  184.00
# 9996                               9.00                  140.43
# 9997                               6.00                  137.80
# 9998                             101.00                   85.00
# 9999                              12.39                  217.00
#
#       piezo_station_longitude  piezo_station_latitude  piezo_producer_code  \
# 0                   -0.671398               45.065936         3.270000e+02
# 1                   -0.244277               47.499944         1.219000e+03
# 2                    1.342298               48.823720         2.910000e+02
# 3                   -1.962030               47.444673         1.219000e+03
# 4                    3.340358               48.456840         2.380000e+02
# ...                       ...                     ...                  ...
# 9995                 1.678606               46.573251         2.930000e+02
# 9996                 7.753676               48.559387         4.049439e+13
# 9997                 4.764418               45.364615         1.960000e+02
# 9998                 0.136413               47.739598         2.272000e+13
# 9999                -1.025439               48.738028         2.910000e+02
#
#       meteo_latitude  meteo_longitude  meteo_altitude  meteo_rain_height  \
# 0          -0.782833        45.214333            26.0                0.2
# 1          -0.167833        47.493167            41.0                0.0
# 2           1.493167        48.801500           132.0                0.2
# 3          -2.105167        47.439667            34.0                0.2
# 4           3.504833        48.439833           102.0                0.2
# ...              ...              ...             ...                ...
# 9995        1.798500        46.598333           211.0                1.7
# 9996        7.768833        48.581833           139.0                3.6
# 9997        4.768667        45.329667           136.0                0.0
# 9998        0.088167        47.713000            92.0                0.2
# 9999       -1.037167        48.794667           336.0                0.4
#
#       meteo_temperature_min  ...  distance_piezo_meteo  \
# 0             -2.400000e+00  ...             18.672882
# 1              1.130000e+01  ...              5.792247
# 2              0.000000e+00  ...             11.320243
# 3              9.200000e+00  ...             10.778974
# 4              1.230000e+01  ...             12.277411
# ...                     ...  ...                   ...
# 9995           5.740806e+07  ...              9.577448
# 9996           4.200000e+00  ...              2.733727
# 9997           2.200000e+00  ...              3.900201
# 9998           6.000000e-01  ...              4.665814
# 9999           9.300000e+00  ...              6.356365
#
#       hydro_observation_result_elab  hydro_longitude  hydro_latitude  \
# 0                              91.0        -0.686723       44.956972
# 1                             636.0        -0.236387       47.454998
# 2                           13452.0         1.376915       48.792029
# 3                           26512.0        -2.126360       47.580112
# 4                            1456.0         3.235083       48.487675
# ...                             ...              ...             ...
# 9995                         3020.0         1.626822       46.665907
# 9996                        44476.0         7.724608       48.571809
# 9997                          726.0         4.731796       45.413262
# 9998                          282.0         0.188533       47.739280
# 9999                         1235.0        -1.016441       48.712120
#
#       distance_piezo_hydro  prelev_other_volume_sum  insee_%_agri  \
# 0                12.175941             9.705931e+07          19.0
# 1                 5.032770             1.862090e+07           8.8
# 2                 4.340942             2.911753e+07           1.3
# 3                19.471344             8.572341e+06           1.0
# 4                 8.484495             2.695328e+08           0.0
# ...                    ...                      ...           ...
# 9995             11.035886             2.787306e+08          25.0
# 9996              2.546237             8.268934e+07           0.1
# 9997              5.979160             3.240429e+09           0.0
# 9998              3.897663             2.211338e+07           4.1
# 9999              2.955513             7.277293e+06           0.0
#
#       insee_pop_commune  insee_%_ind  insee_%_const
# 0                1692.0          6.3           18.5
# 1                5815.0          8.8           12.5
# 2                1588.0         16.6           15.9
# 3                4005.0         18.6           19.8
# 4                 384.0          0.0            8.3
# ...                 ...          ...            ...
# 9995              259.0         31.2            0.0
# 9996           291313.0          4.6            2.1
# 9997             6508.0          5.1           10.5
# 9998             1546.0         20.7            2.8
# 9999               87.0          0.0            0.0
#
# [10000 rows x 29 columns]

# %%
nan_count = num_features.isna().sum()
print(nan_count)
total_nan_count = num_features.isna().sum().sum()
print(total_nan_count)
# Out:
# piezo_station_investigation_depth    0
# piezo_station_altitude               0
# piezo_station_longitude              0
# piezo_station_latitude               0
# piezo_producer_code                  0
# meteo_latitude                       0
# meteo_longitude                      0
# meteo_altitude                       0
# meteo_rain_height                    0
# meteo_temperature_min                0
# meteo_time_tn                        0
# meteo_temperature_max                0
# meteo_time_tx                        0
# meteo_temperature_avg                0
# meteo_temperature_avg_threshold      0
# meteo_frost_duration                 0
# meteo_amplitude_tn_tx                0
# meteo_temperature_avg_tntm           0
# meteo_evapotranspiration_grid        0
# distance_piezo_meteo                 0
# hydro_observation_result_elab        0
# hydro_longitude                      0
# hydro_latitude                       0
# distance_piezo_hydro                 0
# prelev_other_volume_sum              0
# insee_%_agri                         0
# insee_pop_commune                    0
# insee_%_ind                          0
# insee_%_const                        0
# dtype: int64
# 0

# %% [markdown]
# ##### Encoding

# %% [markdown]
# one hot encoding
# ------------------
#
# piezo_station_department_code
#
# piezo_station_department_name
#
# piezo_obtention_mode
#
# piezo_status
#
# piezo_measure_nature_code
#
#
# hydro_status_label
#
# hydro_qualification_code
# hydro_hydro_quantity_elab

# %%
cat_col_features = ["piezo_station_department_code", 
                    "piezo_station_department_name", 
                    "piezo_obtention_mode", 
                    "piezo_status", 
                    "piezo_measure_nature_code", 
                    "hydro_status_label", 
                    "hydro_qualification_code",  
                    "hydro_hydro_quantity_elab"]

col_features = features[cat_col_features]
dfSummary(col_features)

# %% [markdown]
# Pour le moment, on onehot toutes les cat, mais ensuite on pourra essayer un ordinalEncoding qui donne plus d'information au modèle (précise ce qui est mieux ou a plus d'importance grâce à l'ordre)

# %%
one_hot_col_features = cat_col_features
one_hot_features = features[one_hot_col_features]

# on cast juste cette colonne en string elle l'était pas
one_hot_features["hydro_qualification_code"] = one_hot_features["hydro_qualification_code"].astype("str")

# %%
one_hot_features
# Out:
#         piezo_station_department_code piezo_station_department_name  \
# 2613083                            33                       Gironde
# 1268326                            49                Maine-et-Loire
# 234393                             27                          Eure
# 1670802                            44              Loire-Atlantique
# 2804886                            77                Seine-et-Marne
# ...                               ...                           ...
# 28346                              36                         Indre
# 1678943                            67                      Bas-Rhin
# 1784633                            38                         Isère
# 813048                             72                        Sarthe
# 1625530                            50                        Manche
#
#         piezo_obtention_mode               piezo_status  \
# 2613083       Valeur mesurée  Donnée contrôlée niveau 2
# 1268326       Valeur mesurée  Donnée contrôlée niveau 2
# 234393        Valeur mesurée  Donnée contrôlée niveau 2
# 1670802       Valeur mesurée  Donnée contrôlée niveau 2
# 2804886       Valeur mesurée  Donnée contrôlée niveau 2
# ...                      ...                        ...
# 28346         Valeur mesurée  Donnée contrôlée niveau 2
# 1678943       Valeur mesurée  Donnée contrôlée niveau 1
# 1784633       Valeur mesurée  Donnée contrôlée niveau 2
# 813048        Valeur mesurée  Donnée contrôlée niveau 2
# 1625530       Valeur mesurée  Donnée contrôlée niveau 2
#
#         piezo_measure_nature_code  hydro_status_label  \
# 2613083                         N  Donnée pré-validée
# 1268326                         0      Donnée validée
# 234393                          0  Donnée pré-validée
# 1670802                         0      Donnée validée
# 2804886                         N      Donnée validée
# ...                           ...                 ...
# 28346                           N      Donnée validée
# 1678943                         N        Donnée brute
# 1784633                         N      Donnée validée
# 813048                          0      Donnée validée
# 1625530                         N      Donnée validée
#
#         hydro_qualification_code hydro_hydro_quantity_elab
# 2613083                       16                       QmJ
# 1268326                       20                       QmJ
# 234393                        20                       QmJ
# 1670802                       20                       QmJ
# 2804886                       20                       QmJ
# ...                          ...                       ...
# 28346                         20                       QmJ
# 1678943                       16                       QmJ
# 1784633                       20                       QmJ
# 813048                        20                       QmJ
# 1625530                       20                       QmJ
#
# [10000 rows x 8 columns]

# %%
one_hot_features = pd.get_dummies(one_hot_features, drop_first=True)
one_hot_features
# Out:
#          piezo_station_department_code_02  piezo_station_department_code_03  \
# 2613083                             False                             False
# 1268326                             False                             False
# 234393                              False                             False
# 1670802                             False                             False
# 2804886                             False                             False
# ...                                   ...                               ...
# 28346                               False                             False
# 1678943                             False                             False
# 1784633                             False                             False
# 813048                              False                             False
# 1625530                             False                             False
#
#          piezo_station_department_code_04  piezo_station_department_code_05  \
# 2613083                             False                             False
# 1268326                             False                             False
# 234393                              False                             False
# 1670802                             False                             False
# 2804886                             False                             False
# ...                                   ...                               ...
# 28346                               False                             False
# 1678943                             False                             False
# 1784633                             False                             False
# 813048                              False                             False
# 1625530                             False                             False
#
#          piezo_station_department_code_06  piezo_station_department_code_07  \
# 2613083                             False                             False
# 1268326                             False                             False
# 234393                              False                             False
# 1670802                             False                             False
# 2804886                             False                             False
# ...                                   ...                               ...
# 28346                               False                             False
# 1678943                             False                             False
# 1784633                             False                             False
# 813048                              False                             False
# 1625530                             False                             False
#
#          piezo_station_department_code_08  piezo_station_department_code_09  \
# 2613083                             False                             False
# 1268326                             False                             False
# 234393                              False                             False
# 1670802                             False                             False
# 2804886                             False                             False
# ...                                   ...                               ...
# 28346                               False                             False
# 1678943                             False                             False
# 1784633                             False                             False
# 813048                              False                             False
# 1625530                             False                             False
#
#          piezo_station_department_code_10  piezo_station_department_code_11  \
# 2613083                             False                             False
# 1268326                             False                             False
# 234393                              False                             False
# 1670802                             False                             False
# 2804886                             False                             False
# ...                                   ...                               ...
# 28346                               False                             False
# 1678943                             False                             False
# 1784633                             False                             False
# 813048                              False                             False
# 1625530                             False                             False
#
#          ...  piezo_measure_nature_code_D  piezo_measure_nature_code_I  \
# 2613083  ...                        False                        False
# 1268326  ...                        False                        False
# 234393   ...                        False                        False
# 1670802  ...                        False                        False
# 2804886  ...                        False                        False
# ...      ...                          ...                          ...
# 28346    ...                        False                        False
# 1678943  ...                        False                        False
# 1784633  ...                        False                        False
# 813048   ...                        False                        False
# 1625530  ...                        False                        False
#
#          piezo_measure_nature_code_N  piezo_measure_nature_code_S  \
# 2613083                         True                        False
# 1268326                        False                        False
# 234393                         False                        False
# 1670802                        False                        False
# 2804886                         True                        False
# ...                              ...                          ...
# 28346                           True                        False
# 1678943                         True                        False
# 1784633                         True                        False
# 813048                         False                        False
# 1625530                         True                        False
#
#          hydro_status_label_Donnée corrigée  \
# 2613083                               False
# 1268326                               False
# 234393                                False
# 1670802                               False
# 2804886                               False
# ...                                     ...
# 28346                                 False
# 1678943                               False
# 1784633                               False
# 813048                                False
# 1625530                               False
#
#          hydro_status_label_Donnée pré-validée  \
# 2613083                                   True
# 1268326                                  False
# 234393                                    True
# 1670802                                  False
# 2804886                                  False
# ...                                        ...
# 28346                                    False
# 1678943                                  False
# 1784633                                  False
# 813048                                   False
# 1625530                                  False
#
#          hydro_status_label_Donnée validée  hydro_qualification_code_16  \
# 2613083                              False                         True
# 1268326                               True                        False
# 234393                               False                        False
# 1670802                               True                        False
# 2804886                               True                        False
# ...                                    ...                          ...
# 28346                                 True                        False
# 1678943                              False                         True
# 1784633                               True                        False
# 813048                                True                        False
# 1625530                               True                        False
#
#          hydro_qualification_code_20  hydro_hydro_quantity_elab_QmM
# 2613083                        False                          False
# 1268326                         True                          False
# 234393                          True                          False
# 1670802                         True                          False
# 2804886                         True                          False
# ...                              ...                            ...
# 28346                           True                          False
# 1678943                        False                          False
# 1784633                         True                          False
# 813048                          True                          False
# 1625530                         True                          False
#
# [10000 rows x 201 columns]

# %% [markdown]
# ##### Obtenir le dataframe features final

# %%
new_features = cp.deepcopy(features)

new_features[num_col_features] = new_features[num_col_features].replace('N/A - division par 0', np.nan)
new_features[num_col_features] = new_features[num_col_features].replace('nan', np.nan)

for col in num_col_features:
    new_features[col].astype("float")

# %%
imputer_mean_posterior = IterativeImputer(random_state=42, sample_posterior=True)

imputer_mean_posterior.fit(new_features[num_col_features])
values_imputed = imputer_mean_posterior.transform(new_features[num_col_features])

new_features[num_col_features] = values_imputed

# %%
nan_count = new_features[num_col_features].isna().sum()
print(nan_count)
total_nan_count = new_features[num_col_features].isna().sum().sum()
print(total_nan_count)
# Out:
# piezo_station_investigation_depth    0
# piezo_station_altitude               0
# piezo_station_longitude              0
# piezo_station_latitude               0
# piezo_producer_code                  0
# meteo_latitude                       0
# meteo_longitude                      0
# meteo_altitude                       0
# meteo_rain_height                    0
# meteo_temperature_min                0
# meteo_time_tn                        0
# meteo_temperature_max                0
# meteo_time_tx                        0
# meteo_temperature_avg                0
# meteo_temperature_avg_threshold      0
# meteo_frost_duration                 0
# meteo_amplitude_tn_tx                0
# meteo_temperature_avg_tntm           0
# meteo_evapotranspiration_grid        0
# distance_piezo_meteo                 0
# hydro_observation_result_elab        0
# hydro_longitude                      0
# hydro_latitude                       0
# distance_piezo_hydro                 0
# prelev_other_volume_sum              0
# insee_%_agri                         0
# insee_pop_commune                    0
# insee_%_ind                          0
# insee_%_const                        0
# dtype: int64
# 0

# %% [markdown]
# Onehot encoding de new_features:

# %%
new_features.head()
# Out:
#          row_index piezo_station_department_code  \
# 2613083    3067028                            33
# 1268326    1334103                            49
# 234393      246594                            27
# 1670802    1756732                            44
# 2804886    3267483                            77
#
#          piezo_station_investigation_depth  piezo_station_altitude  \
# 2613083                              123.0                    3.59
# 1268326                               93.5                   40.00
# 234393                                12.0                   75.00
# 1670802                                8.0                    5.00
# 2804886                               15.0                   57.50
#
#          piezo_station_longitude  piezo_station_latitude  \
# 2613083                -0.671398               45.065936
# 1268326                -0.244277               47.499944
# 234393                  1.342298               48.823720
# 1670802                -1.962030               47.444673
# 2804886                 3.340358               48.456840
#
#         piezo_measurement_date piezo_obtention_mode  \
# 2613083             2023-03-06       Valeur mesurée
# 1268326             2021-05-21       Valeur mesurée
# 234393              2020-04-04       Valeur mesurée
# 1670802             2021-10-27       Valeur mesurée
# 2804886             2023-05-21       Valeur mesurée
#
#                       piezo_status  piezo_producer_code  ... hydro_longitude  \
# 2613083  Donnée contrôlée niveau 2                327.0  ...       -0.686723
# 1268326  Donnée contrôlée niveau 2               1219.0  ...       -0.236387
# 234393   Donnée contrôlée niveau 2                291.0  ...        1.376915
# 1670802  Donnée contrôlée niveau 2               1219.0  ...       -2.126360
# 2804886  Donnée contrôlée niveau 2                238.0  ...        3.235083
#
#          hydro_latitude  hydro_hydro_quantity_elab  distance_piezo_hydro  \
# 2613083       44.956972                        QmJ             12.175941
# 1268326       47.454998                        QmJ              5.032770
# 234393        48.792029                        QmJ              4.340942
# 1670802       47.580112                        QmJ             19.471344
# 2804886       48.487675                        QmJ              8.484495
#
#         prelev_other_volume_sum  insee_%_agri  insee_pop_commune  insee_%_ind  \
# 2613083            9.705931e+07          19.0             1692.0          6.3
# 1268326            1.862090e+07           8.8             5815.0          8.8
# 234393             2.911753e+07           1.3             1588.0         16.6
# 1670802            8.572341e+06           1.0             4005.0         18.6
# 2804886            2.695328e+08           0.0              384.0          0.0
#
#          insee_%_const  piezo_groundwater_level_category
# 2613083           18.5                           Average
# 1268326           12.5                           Average
# 234393            15.9                              High
# 1670802           19.8                           Average
# 2804886            8.3                          Very Low
#
# [5 rows x 41 columns]

# %%
new_features['DATE_piezo_measurement_date'] = pd.to_datetime(new_features['piezo_measurement_date'])

new_features['year_piezo_measurement'] = new_features['DATE_piezo_measurement_date'].dt.year
new_features['month_piezo_measurement'] = new_features['DATE_piezo_measurement_date'].dt.month
new_features['day_piezo_measurement'] = new_features['DATE_piezo_measurement_date'].dt.day
new_features = new_features.drop(['piezo_measurement_date'], axis=1)

new_features['DATE_meteo_date'] = pd.to_datetime(new_features['meteo_date'])

new_features['year_meteo_date'] = new_features['DATE_meteo_date'].dt.year
new_features['month_meteo_date'] = new_features['DATE_meteo_date'].dt.month
new_features['day_meteo_date'] = new_features['DATE_meteo_date'].dt.day
new_features = new_features.drop(['meteo_date'], axis=1)


new_features['DATE_hydro_observation_date_elab'] = pd.to_datetime(new_features['hydro_observation_date_elab'])

new_features['year_hydro_observation_date_elab'] = new_features['DATE_hydro_observation_date_elab'].dt.year
new_features['month_hydro_observation_date_elab'] = new_features['DATE_hydro_observation_date_elab'].dt.month
new_features['day_hydro_observation_date_elab'] = new_features['DATE_hydro_observation_date_elab'].dt.day
new_features = new_features.drop(['hydro_observation_date_elab'], axis=1)

# %%
new_features_2 = cp.deepcopy(new_features)

# %% [markdown]
# Gérer la variable target pour ne pas la onehotencode

# %%
target_feature = new_features_2.pop(target)
new_features_2.head()
# Out:
#          row_index piezo_station_department_code  \
# 2613083    3067028                            33
# 1268326    1334103                            49
# 234393      246594                            27
# 1670802    1756732                            44
# 2804886    3267483                            77
#
#          piezo_station_investigation_depth  piezo_station_altitude  \
# 2613083                              123.0                    3.59
# 1268326                               93.5                   40.00
# 234393                                12.0                   75.00
# 1670802                                8.0                    5.00
# 2804886                               15.0                   57.50
#
#          piezo_station_longitude  piezo_station_latitude piezo_obtention_mode  \
# 2613083                -0.671398               45.065936       Valeur mesurée
# 1268326                -0.244277               47.499944       Valeur mesurée
# 234393                  1.342298               48.823720       Valeur mesurée
# 1670802                -1.962030               47.444673       Valeur mesurée
# 2804886                 3.340358               48.456840       Valeur mesurée
#
#                       piezo_status  piezo_producer_code  \
# 2613083  Donnée contrôlée niveau 2                327.0
# 1268326  Donnée contrôlée niveau 2               1219.0
# 234393   Donnée contrôlée niveau 2                291.0
# 1670802  Donnée contrôlée niveau 2               1219.0
# 2804886  Donnée contrôlée niveau 2                238.0
#
#         piezo_measure_nature_code  ...  month_piezo_measurement  \
# 2613083                         N  ...                        3
# 1268326                         0  ...                        5
# 234393                          0  ...                        4
# 1670802                         0  ...                       10
# 2804886                         N  ...                        5
#
#          day_piezo_measurement  DATE_meteo_date  year_meteo_date  \
# 2613083                      6       2023-03-06             2023
# 1268326                     21       2021-05-21             2021
# 234393                       4       2020-04-04             2020
# 1670802                     27       2021-10-27             2021
# 2804886                     21       2023-05-21             2023
#
#          month_meteo_date  day_meteo_date  DATE_hydro_observation_date_elab  \
# 2613083                 3               6                        2023-03-06
# 1268326                 5              21                        2021-05-21
# 234393                  4               4                        2020-04-04
# 1670802                10              27                        2021-10-27
# 2804886                 5              21                        2023-05-21
#
#          year_hydro_observation_date_elab  month_hydro_observation_date_elab  \
# 2613083                              2023                                  3
# 1268326                              2021                                  5
# 234393                               2020                                  4
# 1670802                              2021                                 10
# 2804886                              2023                                  5
#
#          day_hydro_observation_date_elab
# 2613083                                6
# 1268326                               21
# 234393                                 4
# 1670802                               27
# 2804886                               21
#
# [5 rows x 49 columns]

# %% [markdown]
# Onehotencode le reste des var catégorielles sauf target

# %%
new_features_2 = pd.get_dummies(new_features_2, drop_first=True)

# %%
new_features_2.head()
# Out:
#          row_index  piezo_station_investigation_depth  piezo_station_altitude  \
# 2613083    3067028                              123.0                    3.59
# 1268326    1334103                               93.5                   40.00
# 234393      246594                               12.0                   75.00
# 1670802    1756732                                8.0                    5.00
# 2804886    3267483                               15.0                   57.50
#
#          piezo_station_longitude  piezo_station_latitude  piezo_producer_code  \
# 2613083                -0.671398               45.065936                327.0
# 1268326                -0.244277               47.499944               1219.0
# 234393                  1.342298               48.823720                291.0
# 1670802                -1.962030               47.444673               1219.0
# 2804886                 3.340358               48.456840                238.0
#
#          meteo_latitude  meteo_longitude  meteo_altitude  meteo_rain_height  \
# 2613083       -0.782833        45.214333            26.0                0.2
# 1268326       -0.167833        47.493167            41.0                0.0
# 234393         1.493167        48.801500           132.0                0.2
# 1670802       -2.105167        47.439667            34.0                0.2
# 2804886        3.504833        48.439833           102.0                0.2
#
#          ...  piezo_status_Donnée contrôlée niveau 2  \
# 2613083  ...                                    True
# 1268326  ...                                    True
# 234393   ...                                    True
# 1670802  ...                                    True
# 2804886  ...                                    True
#
#          piezo_status_Donnée interprétée  piezo_measure_nature_code_D  \
# 2613083                            False                        False
# 1268326                            False                        False
# 234393                             False                        False
# 1670802                            False                        False
# 2804886                            False                        False
#
#          piezo_measure_nature_code_I  piezo_measure_nature_code_N  \
# 2613083                        False                         True
# 1268326                        False                        False
# 234393                         False                        False
# 1670802                        False                        False
# 2804886                        False                         True
#
#          piezo_measure_nature_code_S  hydro_status_label_Donnée corrigée  \
# 2613083                        False                               False
# 1268326                        False                               False
# 234393                         False                               False
# 1670802                        False                               False
# 2804886                        False                               False
#
#          hydro_status_label_Donnée pré-validée  \
# 2613083                                   True
# 1268326                                  False
# 234393                                    True
# 1670802                                  False
# 2804886                                  False
#
#          hydro_status_label_Donnée validée  hydro_hydro_quantity_elab_QmM
# 2613083                              False                          False
# 1268326                               True                          False
# 234393                               False                          False
# 1670802                               True                          False
# 2804886                               True                          False
#
# [5 rows x 149 columns]

# %%
new_features_2[target] = target_feature

# %%
# pd.set_option('display.max_columns', None)

# %%
new_features_2.head()
# Out:
#          row_index  piezo_station_investigation_depth  piezo_station_altitude  \
# 2613083    3067028                              123.0                    3.59
# 1268326    1334103                               93.5                   40.00
# 234393      246594                               12.0                   75.00
# 1670802    1756732                                8.0                    5.00
# 2804886    3267483                               15.0                   57.50
#
#          piezo_station_longitude  piezo_station_latitude  piezo_producer_code  \
# 2613083                -0.671398               45.065936                327.0
# 1268326                -0.244277               47.499944               1219.0
# 234393                  1.342298               48.823720                291.0
# 1670802                -1.962030               47.444673               1219.0
# 2804886                 3.340358               48.456840                238.0
#
#          meteo_latitude  meteo_longitude  meteo_altitude  meteo_rain_height  \
# 2613083       -0.782833        45.214333            26.0                0.2
# 1268326       -0.167833        47.493167            41.0                0.0
# 234393         1.493167        48.801500           132.0                0.2
# 1670802       -2.105167        47.439667            34.0                0.2
# 2804886        3.504833        48.439833           102.0                0.2
#
#          ...  piezo_status_Donnée interprétée  piezo_measure_nature_code_D  \
# 2613083  ...                            False                        False
# 1268326  ...                            False                        False
# 234393   ...                            False                        False
# 1670802  ...                            False                        False
# 2804886  ...                            False                        False
#
#          piezo_measure_nature_code_I  piezo_measure_nature_code_N  \
# 2613083                        False                         True
# 1268326                        False                        False
# 234393                         False                        False
# 1670802                        False                        False
# 2804886                        False                         True
#
#          piezo_measure_nature_code_S  hydro_status_label_Donnée corrigée  \
# 2613083                        False                               False
# 1268326                        False                               False
# 234393                         False                               False
# 1670802                        False                               False
# 2804886                        False                               False
#
#          hydro_status_label_Donnée pré-validée  \
# 2613083                                   True
# 1268326                                  False
# 234393                                    True
# 1670802                                  False
# 2804886                                  False
#
#          hydro_status_label_Donnée validée  hydro_hydro_quantity_elab_QmM  \
# 2613083                              False                          False
# 1268326                               True                          False
# 234393                               False                          False
# 1670802                               True                          False
# 2804886                               True                          False
#
#          piezo_groundwater_level_category
# 2613083                           Average
# 1268326                           Average
# 234393                               High
# 1670802                           Average
# 2804886                          Very Low
#
# [5 rows x 150 columns]

# %%
new_features_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 2613083 to 1625530
# Columns: 150 entries, row_index to piezo_groundwater_level_category
# dtypes: bool(106), datetime64[ns](3), float64(29), int32(9), int64(2), object(1)
# memory usage: 4.1+ MB

# %% [markdown]
# ##### Upload prep x_train to gdrive

# %% [markdown]
# j'ai download les 10k et j'ai upload tout à la main

# %%
new_features_2.to_csv("./data/preprocessed_X_train_Hi5.csv")

# %% [markdown]
# target :
# ------------------
# piezo_groundwater_level_category

# %% [markdown]
# #### Virer les multicolinéarités

# %% [markdown]
# Une fois que c'est encodé on peut encore réduire les dimensions

# %% [markdown]
# ### Data Manipulation

# %% [markdown]
# La valeur de l'intercept peut être interprétée comme étant la valeur en espérance de la variable target
# <br> quand toutes les variables indépendantes sont mises à 0

# %%
# Separate the dependent variable and indepedent variables
Y = df['MEDV_log']

X = df.drop(columns = {'MEDV', 'MEDV_log'})

# Add the intercept term
X = sm.add_constant(X)

# splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30, random_state=1)

# %% [markdown]
# ### Feature Selection/Extraction

# %% [markdown]
# https://machinelearningmastery.com/feature-selection-for-regression-data/
#
# https://medium.com/@satyarepala/tackling-multicollinearity-understanding-variance-inflation-factor-vif-and-mitigation-techniques-2521ebf024b6

# %% [markdown]
# #### **Gérer les multicolinéarités**

# %% [markdown]
# ##### PCA

# %% [markdown]
# Transforme les features en features orthogonales entre elles

# %% [markdown]
# ##### VIF

# %% [markdown]
# #### **Feature Selection**

# %% [markdown]
# ##### Mutual Information

# %% [markdown]
# ##### Correlation feature importance

# %%
# Function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    # Calculating VIF for each feature
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]
    return vif


checking_vif(X_train)
# Out:
#     feature         VIF
# 0     const  535.372593
# 1      CRIM    1.924114
# 2        ZN    2.743574
# 3     INDUS    3.999538
# 4      CHAS    1.076564
# 5       NOX    4.396157
# 6        RM    1.860950
# 7       AGE    3.150170
# 8       DIS    4.355469
# 9       RAD    8.345247
# 10      TAX   10.191941
# 11  PTRATIO    1.943409
# 12    LSTAT    2.861881

# %% [markdown]
# [enlever les variables muticolinéaires & VERIFIER que les multicolinéarités ont disparues]
#
# *   VIF > 5 : éliminé

# %%
# Create the model after dropping TAX
X_train = X_train.drop(columns = 'TAX')

# Check for VIF
print(checking_vif(X_train))
# Out:
#     feature         VIF
# 0     const  532.025529
# 1      CRIM    1.923159
# 2        ZN    2.483399
# 3     INDUS    3.270983
# 4      CHAS    1.050708
# 5       NOX    4.361847
# 6        RM    1.857918
# 7       AGE    3.149005
# 8       DIS    4.333734
# 9       RAD    2.942862
# 10  PTRATIO    1.909750
# 11    LSTAT    2.860251

# %% [markdown]
# #### **Régularisation** - Techniques intégrées dans la régression linéaire

# %% [markdown]
# Faire une :
#
# *   Régression linéaire lasso   L1
# *   Régression linéaire ridge   L2

# %% [markdown]
# ### Predictive Modeling

# %% [markdown]
# Essayer d'utiliser Yellow Brick pour tout ce qui est visualisation des propriétés du modèle.

# %% [markdown]
# #### Modèle 1
#
# R² = 76.9% pas mal mais améliorable

# %%
# Create the model using ordinary least squared
model1 = sm.OLS(y_train,X_train).fit()

# Get the model summary
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MEDV_log   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     103.3
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):          1.40e-101
# Time:                        11:39:50   Log-Likelihood:                 76.596
# No. Observations:                 354   AIC:                            -129.2
# Df Residuals:                     342   BIC:                            -82.76
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6324      0.243     19.057      0.000       4.154       5.111
# CRIM          -0.0128      0.002     -7.445      0.000      -0.016      -0.009
# ZN             0.0010      0.001      1.425      0.155      -0.000       0.002
# INDUS         -0.0004      0.003     -0.148      0.883      -0.006       0.005
# CHAS           0.1196      0.039      3.082      0.002       0.043       0.196
# NOX           -1.0598      0.187     -5.675      0.000      -1.427      -0.692
# RM             0.0532      0.021      2.560      0.011       0.012       0.094
# AGE            0.0003      0.001      0.461      0.645      -0.001       0.002
# DIS           -0.0503      0.010     -4.894      0.000      -0.071      -0.030
# RAD            0.0076      0.002      3.699      0.000       0.004       0.012
# PTRATIO       -0.0452      0.007     -6.659      0.000      -0.059      -0.032
# LSTAT         -0.0298      0.002    -12.134      0.000      -0.035      -0.025
# ==============================================================================
# Omnibus:                       30.699   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.718
# Skew:                           0.372   Prob(JB):                     6.62e-19
# Kurtosis:                       5.263   Cond. No.                     2.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Modèle 2
#
# drop: ZN | AGE | INDUS
#
# R² = 1

# %% [markdown]
# Dans le modèle 1 :
#
# les coefficients suivants ne sont pas statistiquement significativement différents de 0 (seuil de confiance 95%) pour cette population :
#
# *   P(ZN>|t|) = 0.155
# *   P(AGE>|t|) = 0.645
# *   P(INDUS>|t|) = 0.883

# %%
# Create the model after dropping columns 'MEDV', 'MEDV_log', 'TAX', 'ZN', 'AGE', 'INDUS' from df DataFrame
Y = df['MEDV_log']

X = df.drop(['ZN','AGE','INDUS'], axis=1)

X = sm.add_constant(X)

# Splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30 , random_state = 1)

# Create the model
model2 = sm.OLS(y_train,X_train).fit()

# Get the model summary
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MEDV_log   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.690e+29
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:39:50   Log-Likelihood:                 11302.
# No. Observations:                 354   AIC:                        -2.258e+04
# Df Residuals:                     342   BIC:                        -2.253e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.776e-15   7.55e-15     -0.368      0.713   -1.76e-14    1.21e-14
# CRIM       -5.833e-17   3.47e-17     -1.682      0.093   -1.27e-16    9.88e-18
# CHAS       -1.103e-15    6.7e-16     -1.646      0.101   -2.42e-15    2.15e-16
# NOX         9.714e-16   3.06e-15      0.317      0.751   -5.05e-15    6.99e-15
# RM          1.388e-17    3.7e-16      0.038      0.970   -7.14e-16    7.42e-16
# DIS         2.429e-16   1.41e-16      1.725      0.085    -3.4e-17     5.2e-16
# RAD         2.619e-16    5.7e-17      4.596      0.000     1.5e-16    3.74e-16
# TAX        -1.632e-17   2.93e-18     -5.564      0.000   -2.21e-17   -1.05e-17
# PTRATIO     1.409e-16   1.14e-16      1.232      0.219   -8.41e-17    3.66e-16
# LSTAT       3.773e-17   4.74e-17      0.796      0.426   -5.55e-17    1.31e-16
# MEDV        1.919e-16    8.2e-17      2.342      0.020    3.07e-17    3.53e-16
# MEDV_log       1.0000   2.09e-15   4.79e+14      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       10.806   Durbin-Watson:                   0.677
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               17.323
# Skew:                           0.184   Prob(JB):                     0.000173
# Kurtosis:                       4.020   Cond. No.                     1.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Vérification des hypothèses du modèle de régression linéaire

# %% [markdown]
# Si ces hypothèses ne sont pas vérifiées :
#
# *   Indépendance des erreurs (erreurs non corrélées - difficile avec séries temporelles)
# *   Exogénéité (erreurs centrés)
# *   Homoscédasticité (erreurs de variance constante)
# *   Normalité des erreurs (hypothèse plus forte que la 1ère)
#
# -> l'estimation du modèle est possible
# MAIS
# *   estimateur biaisé
# &/ou
#
# *   estimateur non efficace (à variance non minimale)
#
# La normalité des erreurs est non obligatoire mais permet de tirer de bonnes propriétés.

# %% [markdown]
# **Checker sur internet pourquoi ces hypothèses et solution si pas vérifiée**

# %% [markdown]
# ##### 1. Mean of residuals = 0

# %%
residuals = model2.resid
print(np.mean(residuals))
# Out:
# 2.6645352591003757e-15

# %% [markdown]
# ##### 2. Homoscedasticité

# %% [markdown]
# Intérêt :
#
# Être sûr que les coefficients de la régression sont fiables statistiquement.

# %% [markdown]
# Homoscédasticité = Si les résidus sont distribués de manière symétrique sur la ligne de régression,
# <br> on dit que les données sont homoscédastiques.
#
# Hétéroscédasticité = variance des résidus des features différentes
#
# Test Goldfeldquandt avec alpha = 0.05 pour vérifier l'hypothèse :
#
# *   Hypothèse nulle : Les résidus sont homoscedastiques

# %%
name = ["F statistic", "p-value"]
test = sms.het_goldfeldquandt(y_train, X_train)
result = lzip(name, test)
print(result)
print("p-value = ", round(1 - result[1][1], 3))
# Out:
# [('F statistic', 0.7399122694507863), ('p-value', 0.9730778705424925)]
# p-value =  0.027

# %% [markdown]
# p-value < 0.05 => On rejete l'hypothèse nulle avec un seuil de confiance de 95%.
#
# *   Hétéroscédasticité => hypothèse du modèle non vérifiée
# *   Modèle moins précis de façon générale
# *   On peut essayer de résoudre ça en transformant la target variable

# %% [markdown]
# **Solution si heteroscedastique**
#
# https://statisticsbyjim.com/regression/heteroscedasticity-regression/

# %% [markdown]
# **Weighted Linear Regression**

# %% [markdown]
# ##### 3. Relation linéaire entre variable dépendante et indépendantes

# %% [markdown]
# Les features doivent avoir une relation linéaire avec la variable target.
#
# Pour vérifier : les résidus ne doivent pas montrer de pattern, ils doivent être distribués aléatoirement et uniformément suivant l'axe x

# %%
# Predicted values
fitted = model2.fittedvalues

# sns.set_style("whitegrid")
sns.residplot(x = fitted, y = residuals, color = "lightblue", lowess = True)
plt.xlabel("Fitted Values")
plt.ylabel("Residual")
plt.title("Residual PLOT")
plt.show()

# %% [markdown]
# *   Pas de pattern dans résidus vs fitted values
#
# => Hypothèse vérifiée

# %% [markdown]
# ##### 4. Erreurs résiduelles normales (distrib. gaussienne)

# %%
# Plot histogram of residuals

sns.histplot(residuals, kde = True)
plt.show()

stats.probplot(residuals, dist = "norm", plot = pylab)
plt.show()

# %% [markdown]
# *   Les résidus sont skewed
#
# => L'hypothèse n'est pas vérifiée : modèle moins précis de façon générale

# %% [markdown]
# #### Comparaison des résultats

# %% [markdown]
# ##### Evaluation simple d'un modèle

# %%
# Model Performance on test and train data
def model_pref(olsmodel, x_train, x_test):

    # In-sample Prediction
    y_pred_train = olsmodel.predict(x_train)
    y_observed_train = y_train

    # Prediction on test data
    y_pred_test = olsmodel.predict(x_test)
    y_observed_test = y_test


    return pd.DataFrame(
        {
            "Data": ["Train", "Test"],
            "RMSE": [
                rmse(y_pred_train, y_observed_train),
                rmse(y_pred_test, y_observed_test),
            ],
            "MAE": [
                mae(y_pred_train, y_observed_train),
                mae(y_pred_test, y_observed_test),
            ],
            "MAPE": [
                mape(y_pred_train, y_observed_train),
                mape(y_pred_test, y_observed_test),
            ],
            "r2": [
                r2_score(y_pred_train, y_observed_train),
                r2_score(y_pred_test, y_observed_test),
            ],
        }
    )

# Checking model performance
model_pref(model2, X_train, X_test)
# Out:
#     Data          RMSE           MAE          MAPE   r2
# 0  Train  3.298736e-15  2.830128e-15  1.013228e-13  1.0
# 1   Test  3.418333e-15  2.921640e-15  1.037076e-13  1.0

# %% [markdown]
# *   Train & Test scores sont proches et bons, donc le modèle n'est pas overfitté et généralise bien.
# *   Les scores train & test sont si proches que les chances d'améliorer encore les performances de ce modèle

# %% [markdown]
# ##### K-fold Crossvalidation

# %%
# Import the required function


# Build the regression model and cross-validate
linearregression = LinearRegression()                                    

cv_Score11 = cross_val_score(linearregression, X_train, y_train, cv = 10)
cv_Score12 = cross_val_score(linearregression, X_train, y_train, cv = 10, 
                             scoring = 'neg_mean_squared_error')                                  


print("RSquared: %0.3f (+/- %0.3f)" % (cv_Score11.mean(), cv_Score11.std() * 2))
print("Mean Squared Error: %0.3f (+/- %0.3f)" % (-1*cv_Score12.mean(), cv_Score12.std() * 2))
# Out:
# RSquared: 1.000 (+/- 0.000)
# Mean Squared Error: 0.000 (+/- 0.000)

# %% [markdown]
# ##### Le modèle retenu

# %%
coef = model2.params

pd.DataFrame({'Feature' : coef.index, 'Coefs' : coef.values})
# Out:
#      Feature         Coefs
# 0      const -2.775558e-15
# 1       CRIM -5.833008e-17
# 2       CHAS -1.103284e-15
# 3        NOX  9.714451e-16
# 4         RM  1.387779e-17
# 5        DIS  2.428613e-16
# 6        RAD  2.619432e-16
# 7        TAX -1.631724e-17
# 8    PTRATIO  1.409463e-16
# 9      LSTAT  3.773024e-17
# 10      MEDV  1.919038e-16
# 11  MEDV_log  1.000000e+00

# %%
# Let us write the equation of the fit

Equation = "log (Price) = "

print(Equation, end = '\t')

for i in range(len(coef)):
    print('(', coef[i], ') * ', coef.index[i], '+', end = ' ')
# Out:
# log (Price) = 	( -2.7755575615628914e-15 ) *  const + ( -5.833007687972014e-17 ) *  CRIM + ( -1.1032841307212493e-15 ) *  CHAS + ( 9.71445146547012e-16 ) *  NOX + ( 1.3877787807814457e-17 ) *  RM + ( 2.42861286636753e-16 ) *  DIS + ( 2.6194324487249787e-16 ) *  RAD + ( -1.6317242695906842e-17 ) *  TAX + ( 1.4094628242311558e-16 ) *  PTRATIO + ( 3.7730235602495554e-17 ) *  LSTAT + ( 1.9190378452993428e-16 ) *  MEDV + ( 0.9999999999999986 ) *  MEDV_log +

# %% [markdown]
# ## **Weighted Linear Regression**

# %% [markdown]
# Régression linéaire généralisée au cas où l'hypothèse d'homoscedasticité n'est pas vérifiée
#
# https://towardsdatascience.com/weighted-linear-regression-2ef23b12a6d7

# %% [markdown]
# ## **Régression polynomiale**

# %% [markdown]
# ## **Régression DNN**

# %% [markdown]
# ## Autre

# %% [markdown]
# **Utiliser LazyPredict pour déblayer le passage**

# %% [markdown]
# https://www.kaggle.com/code/suneelpatel/compare-ml-models-with-few-lines-of-code
